# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviusfetean/method_name_predictor/blob/main/nlp_codet5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install accelerate peft bitsandbytes transformers trl

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# !pip install pytorch-lightning

# %%
from datasets import load_dataset
import os
methods_dataset = load_dataset("json", data_files={"train":"json_clean_train.json", "test": "json_clean_test.json"})
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
print(methods_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['name', 'body', 'class'],
#         num_rows: 99991
#     })
#     test: Dataset({
#         features: ['name', 'body', 'class'],
#         num_rows: 33331
#     })
# })

# %%
import random

def get_input_text_from_dict(input_dict, add_details=False):
    rand_seed = random.randint(0, 10)
    input_text = ""
    # only teach the model along with additional details in 70% of the cases, letting
    if rand_seed < 7 or add_details:
        input_text += f"<s>class: {input_dict['class']}</s>" if input_dict.get('class', None) is not None else ""
    input_text += f"<s>body: {input_dict['body']}</s>";
    return input_text

# %%
from transformers import RobertaTokenizer

tokenizer = RobertaTokenizer.from_pretrained("Salesforce/codet5-small")

max_input_length = 1024
max_target_length = 128

def convert_dataset(raw_dataset):
    # encode the body-name pairs
    classes = raw_dataset['class']
    bodies = raw_dataset['body']
    names = raw_dataset['name']

    model_inputs = tokenizer(bodies, max_length=max_input_length, padding="max_length", truncation=True)

    # encode the method names
    labels = tokenizer(names, max_length=max_target_length, padding="max_length", truncation=True).input_ids

    # important: we need to replace the index of the padding tokens by -100
    # such that they are not taken into account by the CrossEntropyLoss
    labels_with_ignore_index = []
    for labels_example in labels:
        labels_example = [label if label != 0 else -100 for label in labels_example]
        labels_with_ignore_index.append(labels_example)

    model_inputs["labels"] = labels_with_ignore_index

    return model_inputs
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/703k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/294k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/12.5k [00:00<?, ?B/s]

# %%
dataset = methods_dataset.map(convert_dataset, batched=True)
# Out:
# Map:   0%|          | 0/99991 [00:00<?, ? examples/s]
# Map:   0%|          | 0/33331 [00:00<?, ? examples/s]

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['name', 'body', 'class', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 99991
#     })
#     test: Dataset({
#         features: ['name', 'body', 'class', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 33331
#     })
# })

# %%
#load the dataset in the dataloaders
from torch.utils.data import DataLoader

dataset.set_format(type="torch", columns=['input_ids', 'attention_mask', 'labels'])
train_dataloader = DataLoader(dataset['train'], shuffle=True, batch_size=8)
#test_dataloader = DataLoader(dataset['test'], batch_size=2)

# %%
#example input
batch = next(iter(train_dataloader))
print(batch.keys())
tokenizer.decode(batch['input_ids'][0])
# Out:
# dict_keys(['input_ids', 'attention_mask', 'labels'])
# '<s>return new TextFieldWithPopupHandlerUI.MouseDragAwareCaret();</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>< ...

# %%
#example label
labels = batch['labels'][0]
tokenizer.decode([label for label in labels if label != -100])
# Out:
# '<s>createCaret</s>'

# %%
from transformers import T5ForConditionalGeneration, AdamW, get_linear_schedule_with_warmup
import pytorch_lightning as pl
import torch

class CodeT5(pl.LightningModule):
    def __init__(self, lr=5e-5, num_train_epochs=10, warmup_steps=1000):
        super().__init__()
        self.model = T5ForConditionalGeneration.from_pretrained("/content/drive/MyDrive/llama_output/codet5_method_predictor", device_map={"": 0})
        self.save_hyperparameters()

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        return outputs

    def common_step(self, batch, batch_idx):
        outputs = self(**batch)
        loss = outputs.loss

        return loss

    def training_step(self, batch, batch_idx):
        torch.set_grad_enabled(True)
        loss = self.common_step(batch, batch_idx)
        # logs metrics for each training_step,
        # and the average across the epoch
        self.log("training_loss", loss)

        return loss

    def validation_step(self, batch, batch_idx):
        loss = self.common_step(batch, batch_idx)
        self.log("validation_loss", loss, on_epoch=True)

        return loss

    def test_step(self, batch, batch_idx):
        loss = self.common_step(batch, batch_idx)

        return loss

    def configure_optimizers(self):
        # create optimizer
        optimizer = AdamW(self.parameters(), lr=self.hparams.lr)
        # create learning rate scheduler
        num_train_optimization_steps = self.hparams.num_train_epochs * len(train_dataloader)
        lr_scheduler = {'scheduler': get_linear_schedule_with_warmup(optimizer,
                                                                     num_warmup_steps=self.hparams.warmup_steps,
                                                                     num_training_steps=num_train_optimization_steps),
                        'name': 'learning_rate',
                        'interval':'step',
                        'frequency': 1}

        return {"optimizer": optimizer, "lr_scheduler": lr_scheduler}

    def train_dataloader(self):
        return train_dataloader

# %%
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint

model = CodeT5()

lr_monitor = LearningRateMonitor(logging_interval='step')

trainer = Trainer(callbacks=[lr_monitor], max_epochs=5)
trainer.fit(model)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 60.5 M
# -----------------------------------------------------
# 60.5 M    Trainable params
# 0         Non-trainable params
# 60.5 M    Total params
# 241.969   Total estimated model params size (MB)
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.

# %%
model.model.save_pretrained('/content/drive/MyDrive/llama_output/codet5_method_predictor')

# %%
#load the checkpointed model
model = T5ForConditionalGeneration.from_pretrained("/content/drive/MyDrive/llama_output/codet5_method_predictor",
                                                    device_map={"": 0})
original_model = T5ForConditionalGeneration.from_pretrained("Salesforce/codet5-small",  cache_dir=r"/content/drive/MyDrive/llama_output",
                                                                device_map={"": 0})

# %%
# prepare for the model
test_dict = methods_dataset['test'][22]
print(f"Inferencing for: {test_dict['body']}")
input_ids = tokenizer(test_dict['body'], return_tensors='pt').input_ids.to('cuda')
input_ids_orig = tokenizer("Generate a method name for the body: " + test_dict['body'], return_tensors='pt').input_ids.to('cuda')
# generate
outputs = model.generate(input_ids)
outputs_original = original_model.generate(input_ids_orig)
print("Generated name by the fine-tuned model:", tokenizer.decode(outputs[0], skip_special_tokens=True))
print("Generated name by the original model:", tokenizer.decode(outputs_original[0], skip_special_tokens=True))
print("Ground truth: ", test_dict['name'])
# Out:
# Inferencing for: setErrorMessage(errorMessage);
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Generated name by the fine-tuned model: setErrorMessage
# Generated name by the original model:  public void
# Ground truth:  errorOccurred

# %% [markdown]
# #Testing the result model
#
#
# 1.   **Hard Comparison**:
#   The output is tested for an exact match

# %%
def compare_outputs(pred, gt):
    return 1 if pred == gt else 0

# %% [markdown]
# 2.   **Soft comparison (similarity)**: We will count the number of words that appear in both the output and the ground truth, as the output may still have relevance even if not an exact match

# %%
def split_camel_case(input_string):
    """
    Method to split a method name which is known to be a camel-case
    into its composing words (Java convention)
    """
    try:
        words = [input_string[0]]

        for char in input_string[1:]:
            if char.isupper():
                words.append(char.lower())
            else:
                words[-1] += char
    except IndexError:
        return ""

    return ' '.join(words)

camel_case_string = "camelCaseExample"
result = split_camel_case(camel_case_string)
print(result)
# Out:
# camel case example

# %%
def compare_similarity(pred, gt):
    """Often the method name is not predicted exactly the same as the ground truth
    But it is composed of some words that are also present in the ground truth
    Therefore, we will consider the similarity between the results as the number of words in the ground truth that are also present in the prediction divided by the maximum length of the two strings
    """

    max_similarity = 0
    words = split_camel_case(gt).split()
    for word in words:
        if word in pred.lower():
            max_similarity += len(word)

    return max_similarity / max(len(pred), len(gt))

# %% [markdown]
# 3.   **ROUGE score**: A generalization of the soft score, will also take into account bigrams and longest-common-sequences

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install evaluate absl-py rouge_score nltk
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.16.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.23.5)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (23.2)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.13.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.3.post1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=91fa4f6fc2210a1f83ca89d133b64603f9e9efc072eb897c276ccec2e82e89b0
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score, responses, evaluate
# Successfully installed evaluate-0.4.1 responses-0.18.0 rouge_score-0.1.2

# %%
import evaluate

rouge = evaluate.load('rouge')

def compare_rouge(preds, gts):
    """
    Rouge will treat the texts as summaries, so we will have to split
    the method names into composing words and treat them as summaries
    """
    pred_split = [split_camel_case(pred) for pred in preds]
    gt_split = [split_camel_case(gt) for gt in gts]

    return rouge.compute(predictions=pred_split, references=gt_split)

print(compare_rouge(["getTestDefault"], ["myTestNotDefault"])) #Expected 0.57 r1, 0 r2, 0.57 rl
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.5714285714285715, 'rouge2': 0.0, 'rougeL': 0.5714285714285715, 'rougeLsum': 0.5714285714285715}

# %%
#test the compare functions
print(compare_outputs("hello", "hello")) #Expected 1
print(compare_outputs("hello", "world")) #Expected 0
print(compare_similarity("hello", "hello")) #Expected 1.0
print(compare_similarity("hello", "hell")) #Expected 0.8
print(compare_similarity("hello", "helll")) #Expected 0.0
print(compare_similarity("getTestDefault", "myTestNotDefault")) #Expected 0.687
# Out:
# 1
# 0
# 1.0
# 0.8
# 0.0
# 0.6875

# %% [markdown]
# Method to predict on all inputs, given a model and a dataset (dataset must be formatted for the model input)

# %%
from tqdm import tqdm

def predict_all(model, dataset, tokenizer, max_new_tokens=20):
    #turn of learning functions
    model.eval()
    torch.no_grad()

    #innitialize lists for predictions and ground truths that will be comppared
    predictions = []
    gt = []
    for i, example in enumerate(dataset):
        #prepare input
        input_ids = tokenizer(example['input'], return_tensors='pt').input_ids.to('cuda')
        # generate
        outputs = model.generate(input_ids, max_new_tokens=max_new_tokens)
        #decode predicate and add to list
        pred = tokenizer.decode(outputs[0], skip_special_tokens=True)
        predictions.append(pred)
        gt.append(example['label'])
        if i%1000 == 0:
            print(f"{i}/{len(dataset)}")
    return predictions, gt

# %% [markdown]
# Cell to evaluate predictions on soft, hard and rouge scores

# %%
#evaluate the predictions

def evaluate_predictions(predictions, gt):
    hard_score = 0
    soft_score = 0

    for i, (pred, gndt) in enumerate(zip(predictions, gt)):
        hard_score += compare_outputs(pred, gndt)
        soft_score += compare_similarity(pred, gndt)

    print("Hard score: ", hard_score / len(predictions))
    print("Soft score: ", soft_score / len(predictions))
    print("Rouge score: ", compare_rouge(predictions, gt))

# %% [markdown]
# Evaluate the fine-tuned model

# %%
#get all predictions
model_input = [{"input": example['body'], "label": example['name']} for example in methods_dataset['test']]
predictions, gt = predict_all(model, model_input, tokenizer)
# Out:
# 0/33331
# 1000/33331
# 2000/33331
# Token indices sequence length is longer than the specified maximum sequence length for this model (723 > 512). Running this sequence through the model will result in indexing errors
# 3000/33331
# 4000/33331
# 5000/33331
# 6000/33331
# 7000/33331
# 8000/33331
# 9000/33331
# 10000/33331
# 11000/33331
# 12000/33331
# 13000/33331
# 14000/33331
# 15000/33331
# 16000/33331
# 17000/33331
# 18000/33331
# 19000/33331
# 20000/33331
# 21000/33331
# 22000/33331
# 23000/33331
# 24000/33331
# 25000/33331
# 26000/33331
# 27000/33331
# 28000/33331
# 29000/33331
# 30000/33331
# 31000/33331
# 32000/33331
# 33000/33331

# %%
evaluate_predictions(predictions, gt)
# Out:
# Datele de ieșire de afișat au fost trunchiate la ultimele 5000 linii.
# Ground truth:  dispose
# Predicted:  isEnabledByDefault
# Ground truth:  isWritable
# Predicted:  documentChanged
# Ground truth:  documentChanged
# Predicted:  removeElement
# Ground truth:  poll
# Predicted:  addListener
# Ground truth:  addRootSetChangedListener
# Predicted:  isAvailable
# Ground truth:  isAvailableOnElementInEditorAndFile
# Predicted:  getTree
# Ground truth:  createCenterPanel
# Predicted:  matchAdjustmentDelimiters
# Ground truth:  matchAdjustmentDelimiters
# Predicted:  setSelectedModuleJdk
# Ground truth:  reset
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  isEnabledByDefault
# Ground truth:  existsFieldWithName
# Predicted:  getSubstitutor
# Ground truth:  getSubstitutor
# Predicted:  getCanonicalText
# Ground truth:  getQualifiedName
# Predicted:  isAllowedField
# Ground truth:  hasSafeType
# Predicted:  isEnabledByDefault
# Ground truth:  isInComments
# Predicted:  setHelpId
# Ground truth:  setHelpId
# Predicted:  fillTransparencyHoverColor
# Ground truth:  paintHover
# Predicted:  find
# Ground truth:  log
# Predicted:  setFoo
# Ground truth:  setFoo
# Predicted:  clearControllerMessage
# Ground truth:  clearControllerMessage
# Predicted:  equals
# Ground truth:  equals
# Predicted:  registerHighlightingPassFactory
# Ground truth:  registerHighlightingPassFactory
# Predicted:  getType
# Ground truth:  getInterfaceType
# Predicted:  registerUser
# Ground truth:  readCurrentUser
# Predicted:  getIcon
# Ground truth:  getIcon
# Predicted:  getVersion
# Ground truth:  getVersion
# Predicted:  removeOutput
# Ground truth:  removeOutput
# Predicted:  addExpression
# Ground truth:  setTemplate
# Predicted:  loadState
# Ground truth:  loadState
# Predicted:  generate
# Ground truth:  generateWhiteSpace
# Predicted:  visitMethodCallExpression
# Ground truth:  visitCallExpression
# Predicted:  setType
# Ground truth:  updateFromMethod
# Predicted:  showWarningDialog
# Ground truth:  showWarningDialog
# Predicted:  getRefactoringName
# Ground truth:  getRefactoringName
# Predicted:  getFirstChild
# Ground truth:  getFirstChild
# Predicted:  getStartOffset
# Ground truth:  getOffsetInHost
# Predicted:  createSession
# Ground truth:  createVerboseSession
# Predicted:  reset
# Ground truth:  reset
# Predicted:  textMatches
# Ground truth:  textMatches
# Predicted:  hasModifierProperty
# Ground truth:  hasModifier
# Predicted:  getState
# Ground truth:  getPreferredFocusableComponent
# Predicted:  getFilter
# Ground truth:  getFilter
# Predicted:  areErasedParametersEqual
# Ground truth:  areOverrideEquivalent
# Predicted:  hasMultipleRepositories
# Ground truth:  moreThanOneRoot
# Predicted:  main
# Ground truth:  main
# Predicted:  customizeCellRenderer
# Ground truth:  getTreeCellRendererComponent
# Predicted:  getChildRole
# Ground truth:  getChildRole
# Predicted:  getPath
# Ground truth:  getFilePath
# Predicted:  getHighlighter
# Ground truth:  getHighlighter
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  createNormalIndent
# Ground truth:  createNormalIndent
# Predicted:  visitTypeArgument
# Ground truth:  visitTypeArgument
# Predicted:  getLayerDiff
# Ground truth:  compare
# Predicted:  setOneLineMode
# Ground truth:  build
# Predicted:  extensionRemoved
# Ground truth:  sessionCreated
# Predicted:  removeAll
# Ground truth:  removeAll
# Predicted:  isEnabledByDefault
# Ground truth:  useMiddleMatching
# Predicted:  createFile
# Ground truth:  createFile
# Predicted:  shouldInspect
# Ground truth:  accept
# Predicted:  parseJavaCodeReference
# Ground truth:  parseImportCodeReference
# Predicted:  isEnabled
# Ground truth:  isTabbingModeAvailable
# Predicted:  getCompilerOutputPath
# Ground truth:  getClasspathEntry
# Predicted:  removeDistinctClassPair
# Ground truth:  mergeDistinctPairs
# Predicted:  getWordOrLexemeSelectionRange
# Ground truth:  getWordSelectionRange
# Predicted:  visitMethodCallExpression
# Ground truth:  actionPerformed
# Predicted:  findVersion
# Ground truth:  findVersion
# Predicted:  getQualifiedName
# Ground truth:  getUniqueId
# Predicted:  getButtonHeight
# Ground truth:  getIncrementButtonHeight
# Predicted:  getNestedResult
# Ground truth:  getNestedResult
# Predicted:  visitReferenceElement
# Ground truth:  merge
# Predicted:  context
# Ground truth:  context
# Predicted:  browse
# Ground truth:  hyperlinkActivated
# Predicted:  setTextBg
# Ground truth:  setTextBg
# Predicted:  isMayOverflow
# Ground truth:  mayOverflow
# Predicted:  collectFiles
# Ground truth:  addFilesTo
# Predicted:  toString
# Ground truth:  toString
# Predicted:  enableTools
# Ground truth:  enableToolsByDefault
# Predicted:  disable
# Ground truth:  beDisabled
# Predicted:  isInheritor
# Ground truth:  inheritorOf
# Predicted:  dispose
# Ground truth:  dispose
# Predicted:  isEnabledByDefault
# Ground truth:  isAvailableInEditorOnly
# Predicted:  visitMethodCallExpression
# Ground truth:  paintChildren
# Predicted:  getParentNode
# Ground truth:  getGroup
# Predicted:  visitIfStatement
# Ground truth:  visitIfStatement
# Predicted:  withExcludedInGutter
# Ground truth:  withExcludedInGutter
# Predicted:  update
# Ground truth:  update
# Predicted:  getLocationOnScreen
# Ground truth:  getComponentLocationOnScreen
# Predicted:  getContentId
# Ground truth:  getContentPathName
# Predicted:  isEnabledByDefault
# Ground truth:  generateUniqueServerName
# Predicted:  isInheritorDeep
# Ground truth:  isInheritorDeep
# Predicted:  drop
# Ground truth:  dropTypeConstraint
# Predicted:  isGenerateDelegate
# Ground truth:  isGenerateDelegate
# Predicted:  updateLineWidthIfNecessary
# Ground truth:  onLineWidthsChange
# Predicted:  reset
# Ground truth:  clearCachedTokenType
# Predicted:  isPlain
# Ground truth:  isPlain
# Predicted:  hasNext
# Ground truth:  hasNextOccurence
# Predicted:  findIterableForLambda
# Ground truth:  findIterable
# Predicted:  bindReferenceTo
# Ground truth:  applyFix
# Predicted:  setBouncing
# Ground truth:  clearAttraction
# Predicted:  isApplicable
# Ground truth:  isClass
# Predicted:  addData
# Ground truth:  refreshModelImmediately
# Predicted:  getGapBetweenAnnotations
# Ground truth:  getGapBetweenAnnotations
# Predicted:  isEnabledByDefault
# Ground truth:  startInWriteAction
# Predicted:  isEnabledByDefault
# Ground truth:  variableValueIsUsed
# Predicted:  getPrevTokenEnd
# Ground truth:  getPrevTokenEnd
# Predicted:  reset
# Ground truth:  clearDiffPresentation
# Predicted:  hashCode
# Ground truth:  hashCode
# Predicted:  postProcess
# Ground truth:  postProcess
# Predicted:  getObjectOverloadedString
# Ground truth:  get
# Predicted:  setSdkName
# Ground truth:  setSdkName
# Predicted:  isFailed
# Ground truth:  shouldStop
# Predicted:  isFile
# Ground truth:  seemsScrambled
# Predicted:  parseClass
# Ground truth:  parseSnippetAttribute
# Predicted:  getElementAt
# Ground truth:  getElement
# Predicted:  actionPerformed
# Ground truth:  documentChanged
# Predicted:  isIgnoreParensWraps
# Ground truth:  getIgnoreParentWraps
# Predicted:  getInstance
# Ground truth:  getInstance
# Predicted:  isEnabledByDefault
# Ground truth:  isAutoBoxed
# Predicted:  getAttributes
# Ground truth:  getAttributes
# Predicted:  addFile
# Ground truth:  checkMovedAddedSourceBack
# Predicted:  addFacet
# Ground truth:  addFacet
# Predicted:  hasInvalidFacets
# Ground truth:  isVisible
# Predicted:  getName
# Ground truth:  getName
# Predicted:  visitBlockStatement
# Ground truth:  visitBlockStatement
# Predicted:  isInterface
# Ground truth:  isInterface
# Predicted:  isChildrenValidMappings
# Ground truth:  areChildrenValidMappings
# Predicted:  isSelected
# Ground truth:  isFileTypeSelected
# Predicted:  isApplicable
# Ground truth:  removeInsetsBeforeLayout
# Predicted:  actionPerformed
# Ground truth:  handleScopeChooserAction
# Predicted:  visitMethodCallExpression
# Ground truth:  copyTypeParameterListIfNotReplaced
# Predicted:  getCaretOffset
# Ground truth:  getVisibleOffset
# Predicted:  getFilePath
# Ground truth:  getRelativePath
# Predicted:  visitMethodCallExpression
# Ground truth:  setProgressTask
# Predicted:  registerConflictResolvers
# Ground truth:  doChangeSignature
# Predicted:  isConditionNecessary
# Ground truth:  areConditionsNecessaryFor
# Predicted:  getSize
# Ground truth:  getRowCount
# Predicted:  getColumnCount
# Ground truth:  size
# Predicted:  isEnabledByDefault
# Ground truth:  isShowFileIndentOptionsEnabled
# Predicted:  applyFix
# Ground truth:  applyFix
# Predicted:  lookupStarted
# Ground truth:  lookupStubEntriesStarted
# Predicted:  addClassIntrospector
# Ground truth:  visitAntDomCustomElement
# Predicted:  isJavaLangString
# Ground truth:  isStringType
# Predicted:  addProportions
# Ground truth:  doSaveSplitterProportions
# Predicted:  visitMethodCallExpression
# Ground truth:  visitStatement
# Predicted:  getTitle
# Ground truth:  getCommandName
# Predicted:  selectAllOccurrences
# Ground truth:  allOccurrencesFromEditor
# Predicted:  getPreferredSize
# Ground truth:  getButtonDimension
# Predicted:  isWithinTab
# Ground truth:  isTouchScroll
# Predicted:  doCompare
# Ground truth:  keyPressed
# Predicted:  repaint
# Ground truth:  focusLost
# Predicted:  isEnabledByDefault
# Ground truth:  withSeparators
# Predicted:  getParent
# Ground truth:  getParent
# Predicted:  getData
# Ground truth:  getData
# Predicted:  stripNotMnemonic
# Ground truth:  getTextWithoutMnemonicEscaping
# Predicted:  buildFix
# Ground truth:  buildFix
# Predicted:  setSourceFilePathBytes
# Ground truth:  setSourceFilePathBytes
# Predicted:  visitMethodCallExpression
# Ground truth:  actionPerformed
# Predicted:  updateText
# Ground truth:  updateActionText
# Predicted:  isEnabledByDefault
# Ground truth:  isQualified
# Predicted:  isEnabledByDefault
# Ground truth:  hasGenericTypeParameters
# Predicted:  getIcon
# Ground truth:  getIcon
# Predicted:  getDescription
# Ground truth:  getDescription
# Predicted:  isEnabledByDefault
# Ground truth:  isReferenceTo
# Predicted:  isWritable
# Ground truth:  isWritable
# Predicted:  isComponentUnderMouse
# Ground truth:  isSelected
# Predicted:  doExecute
# Ground truth:  invoke
# Predicted:  selectTargets
# Ground truth:  selectTargets
# Predicted:  isEnabledByDefault
# Ground truth:  isSaveActionApplicable
# Predicted:  visitMethodCallExpression
# Ground truth:  paintComponent
# Predicted:  setValueAt
# Ground truth:  setValueAt
# Predicted:  update
# Ground truth:  update
# Predicted:  visitMethodCallExpression
# Ground truth:  visitCatchSection
# Predicted:  setCloneParentDir
# Ground truth:  setCloneParentDir
# Predicted:  actionPerformed
# Ground truth:  setBreadcrumbs
# Predicted:  clearTargetId
# Ground truth:  clearTargetId
# Predicted:  createJBLabelDecorator
# Ground truth:  createJBLabelDecorator
# Predicted:  searchStarted
# Ground truth:  onSearchStarted
# Predicted:  getFormattedString
# Ground truth:  getMacFormat
# Predicted:  computeValue
# Ground truth:  computeConstant
# Predicted:  createPreviousOccurenceAction
# Ground truth:  createPrevOccurenceAction
# Predicted:  setHighlighter
# Ground truth:  updatePreviewHighlighter
# Predicted:  paintComponent
# Ground truth:  paintTabBackground
# Predicted:  replaceAll
# Ground truth:  add
# Predicted:  getInstance
# Ground truth:  getInstance
# Predicted:  setText
# Ground truth:  add
# Predicted:  getTaskActivator
# Ground truth:  getTaskActivator
# Predicted:  isStreamType
# Ground truth:  isMyQualifierType
# Predicted:  setActionGroup
# Ground truth:  setParentGroupName
# Predicted:  getMetaDataRegistrar
# Ground truth:  getInstance
# Predicted:  getIcon
# Ground truth:  detectVersion
# Predicted:  perform
# Ground truth:  perform
# Predicted:  addActionListener
# Ground truth:  addActionListener
# Predicted:  createElement
# Ground truth:  copyTo
# Predicted:  print
# Ground truth:  simpleIfCondition
# Predicted:  registerRefactoring
# Ground truth:  createReplaceFieldsWithGettersPanel
# Predicted:  get
# Ground truth:  getNode
# Predicted:  setSymbols
# Ground truth:  setSymbols
# Predicted:  isAssigned
# Ground truth:  isConfigurationAssigned
# Predicted:  main
# Ground truth:  getItemCountImpl
# Predicted:  isReplaceAll
# Ground truth:  isReplaceAll
# Predicted:  getRangeInElement
# Ground truth:  getRangeInElement
# Predicted:  restoreKeepers
# Ground truth:  restorePosition
# Predicted:  getDisplayName
# Ground truth:  getDisplayName
# Predicted:  getT1
# Ground truth:  param2
# Predicted:  visitMethodCallExpression
# Ground truth:  visitReferenceExpression
# Predicted:  setPlaceholderAttributes
# Ground truth:  setPlaceholderAttributes
# Predicted:  push
# Ground truth:  build
# Predicted:  getName
# Ground truth:  getName
# Predicted:  main
# Ground truth:  method
# Predicted:  isDocComment
# Ground truth:  isDocumentationComment
# Predicted:  getTextComponentBounds
# Ground truth:  getVisibleEditorRect
# Predicted:  isValid
# Ground truth:  isValid
# Predicted:  getComponentName
# Ground truth:  getComponentName
# Predicted:  visitMethodCallExpression
# Ground truth:  scanForRootsAboveDir
# Predicted:  getTextFor
# Ground truth:  getTextFor
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  getReplaceInPathShortcut
# Ground truth:  getShortcut
# Predicted:  method
# Ground truth:  method
# Predicted:  isEnabledByDefault
# Ground truth:  isEnabledByDefault
# Predicted:  setOpenRunningConfigInTab
# Ground truth:  setOpenRunningConfigInNewTab
# Predicted:  getColumnCount
# Ground truth:  getWeight
# Predicted:  getEditor
# Ground truth:  getEditor
# Predicted:  actionPerformed
# Ground truth:  setupUpKey
# Predicted:  equals
# Ground truth:  equals
# Predicted:  setSoftWrapFileMask
# Ground truth:  setSoftWrapFileMasks
# Predicted:  isStringToken
# Ground truth:  isStringLiteral
# Predicted:  getSourceComponent
# Ground truth:  getSourceComponent
# Predicted:  main
# Ground truth:  foo
# Predicted:  update
# Ground truth:  update
# Predicted:  setTextWithMnemonic
# Ground truth:  setTextWithMnemonic
# Predicted:  extensionRemoved
# Ground truth:  modificationCountChanged
# Predicted:  next
# Ground truth:  nextId
# Predicted:  findModel
# Ground truth:  getFindModel
# Predicted:  remove
# Ground truth:  remove
# Predicted:  foo
# Ground truth:  foo
# Predicted:  paintComponent
# Ground truth:  paintComponent
# Predicted:  trace
# Ground truth:  trace
# Predicted:  getState
# Ground truth:  getLogUiState
# Predicted:  displayTextInToolbar
# Ground truth:  displayTextInToolbar
# Predicted:  getStartingRevisionNumber
# Ground truth:  getRevision
# Predicted:  getFactory
# Ground truth:  supply
# Predicted:  dispose
# Ground truth:  update
# Predicted:  foo
# Ground truth:  run
# Predicted:  isUseLigatures
# Ground truth:  isUseLigatures
# Predicted:  update
# Ground truth:  actionPerformed
# Predicted:  equals
# Ground truth:  isSuperType
# Predicted:  getNodeProvider
# Ground truth:  getNodeProvider
# Predicted:  add
# Ground truth:  onMouseClicked
# Predicted:  addSystemClipboardContent
# Ground truth:  setContents
# Predicted:  isEnabledByDefault
# Ground truth:  nameResolvedSuccessfully
# Predicted:  acceptChildren
# Ground truth:  acceptChildren
# Predicted:  equals
# Ground truth:  equals
# Predicted:  consumeToken
# Ground truth:  consumeTokenFast
# Predicted:  getJdk
# Ground truth:  getAlternativeJre
# Predicted:  isEnabledByDefault
# Ground truth:  isAlwaysShowPlus
# Predicted:  setCursor
# Ground truth:  onMouseMove
# Predicted:  isEnum
# Ground truth:  isEnum
# Predicted:  setModuleOptions
# Ground truth:  setModuleOptionsMap
# Predicted:  mousePressed
# Ground truth:  noneSelected
# Predicted:  hasPrevious
# Ground truth:  hasNext
# Predicted:  meth
# Ground truth:  meth
# Predicted:  getImportReferenceText
# Ground truth:  getQualifiedName
# Predicted:  updateIcon
# Ground truth:  setIcon
# Predicted:  findChild
# Ground truth:  charAt
# Predicted:  getIcon
# Ground truth:  getPrevWindow
# Predicted:  perform
# Ground truth:  performPsiSpoilingRefactoring
# Predicted:  showCustomOption
# Ground truth:  showCustomOption
# Predicted:  setTrader
# Ground truth:  setTrader
# Predicted:  equals
# Ground truth:  equals
# Predicted:  value
# Ground truth:  value
# Predicted:  getLanguageLevel
# Ground truth:  getDefaultLanguageLevel
# Predicted:  commentLeadingAsterisks
# Ground truth:  commentLeadingAsterisks
# Predicted:  applyFix
# Ground truth:  appendAdditionalListItemInfo
# Predicted:  isStreamHolder
# Ground truth:  isStreamHoldingResource
# Predicted:  receive
# Ground truth:  receive
# Predicted:  clone
# Ground truth:  cloneTemplateConfiguration
# Predicted:  remove
# Ground truth:  replace
# Predicted:  getTypeParameter
# Ground truth:  findPsiTypeForPredicate
# Predicted:  run
# Ground truth:  run
# Predicted:  isEnabledByDefault
# Ground truth:  vetoesHiding
# Predicted:  collectAdditionalConstraints
# Ground truth:  processReturnExpression
# Predicted:  encodeInfoInTypeElement
# Ground truth:  encodeClassTypeInfoInReference
# Predicted:  updateCacheAndRepaint
# Ground truth:  componentResized
# Predicted:  addListener
# Ground truth:  addExtensionPointListener
# Predicted:  isModified
# Ground truth:  isModified
# Predicted:  getStatus
# Ground truth:  getCurrentStatus
# Predicted:  meth
# Ground truth:  meth
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  update
# Ground truth:  update
# Predicted:  headerSize
# Ground truth:  headerSize
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  isHighlightingAvailable
# Ground truth:  isValidForFile
# Predicted:  getId
# Ground truth:  getId
# Predicted:  getFileType
# Ground truth:  getFileType
# Predicted:  assertInlayOffsetCount
# Ground truth:  assertInlaysPositions
# Predicted:  processDeclarations
# Ground truth:  processDeclarations
# Predicted:  saveData
# Ground truth:  saveData
# Predicted:  deleteFile
# Ground truth:  deleteTempFile
# Predicted:  getFileSet
# Ground truth:  getFileSet
# Predicted:  preferredLayoutSize
# Ground truth:  textChanged
# Predicted:  getPosition
# Ground truth:  getPosition
# Predicted:  setAutoScroll
# Ground truth:  setAutoScroll
# Predicted:  doInjectInJava
# Ground truth:  addInjectionInPlace
# Predicted:  set
# Ground truth:  fail
# Predicted:  getInstance
# Ground truth:  getInstance
# Predicted:  set
# Ground truth:  delete
# Predicted:  addRunner
# Ground truth:  createEditor
# Predicted:  reset
# Ground truth:  goTo
# Predicted:  getIcon
# Ground truth:  getStartElement
# Predicted:  mouseExited
# Ground truth:  registerHint
# Predicted:  put
# Ground truth:  setBinding
# Predicted:  isShiftOperation
# Ground truth:  isShiftToken
# Predicted:  compare
# Ground truth:  compareTrimWhitespaces
# Predicted:  processTemplate
# Ground truth:  shortenReferences
# Predicted:  isAdded
# Ground truth:  baseExistsOrAdded
# Predicted:  addDefaultConstructor
# Ground truth:  invoke
# Predicted:  customizeCellRenderer
# Ground truth:  getTableCellRendererComponent
# Predicted:  getData
# Ground truth:  getData
# Predicted:  getIcon
# Ground truth:  getIcon
# Predicted:  isSchemeMutable
# Ground truth:  canDeleteScheme
# Predicted:  subList
# Ground truth:  subQualifiedName
# Predicted:  getChangeTracker
# Ground truth:  getTracker
# Predicted:  isEnabledByDefault
# Ground truth:  createReferences
# Predicted:  visitMethod
# Ground truth:  dispreferPreviousChainCalls
# Predicted:  getInclude
# Ground truth:  isInclude
# Predicted:  accept
# Ground truth:  accept
# Predicted:  isEnabled
# Ground truth:  isNewServicesUIEnabled
# Predicted:  getLastCharInFile
# Ground truth:  getRelativePathPrefix
# Predicted:  getInspection
# Ground truth:  getInspection
# Predicted:  getClasspathFile
# Ground truth:  isClasspathFile
# Predicted:  endsWith
# Ground truth:  endsWith
# Predicted:  isApplicable
# Ground truth:  isAvailable
# Predicted:  getNextSibling
# Ground truth:  doMoveMethod
# Predicted:  isAvailableForQuickList
# Ground truth:  isValidForFile
# Predicted:  getData
# Ground truth:  getData
# Predicted:  isEnabledByDefault
# Ground truth:  bar
# Predicted:  getState
# Ground truth:  getDeclaration
# Predicted:  getFoo
# Ground truth:  getFoo
# Predicted:  getPath
# Ground truth:  getPath
# Predicted:  get
# Ground truth:  component
# Predicted:  createUsage
# Ground truth:  createRootUsage
# Predicted:  visitMethodCallExpression
# Ground truth:  updateBreakpointPresentation
# Predicted:  isPasteEnabled
# Ground truth:  isEnabled
# Predicted:  getDisplayName
# Ground truth:  suggestedName
# Predicted:  isNewLocal
# Ground truth:  isNewLocal
# Predicted:  setSourceUri
# Ground truth:  addIdentifierBytes
# Predicted:  isNegated
# Ground truth:  isArgumentLambdaNegated
# Predicted:  assertEquals
# Ground truth:  assertEquals
# Predicted:  getValue
# Ground truth:  valueToString
# Predicted:  getCompilerOutputFilePath
# Ground truth:  getCompilerOutput
# Predicted:  visitLambdaExpression
# Ground truth:  visitLambdaExpression
# Predicted:  meth
# Ground truth:  meth
# Predicted:  isEnabledByDefault
# Ground truth:  containsSecondLevelNodes
# Predicted:  getPresentableFile
# Ground truth:  getIconForUrl
# Predicted:  mouseEntered
# Ground truth:  update
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  getStepsCount
# Ground truth:  getNumberOfSteps
# Predicted:  getFilePathOn
# Ground truth:  getFilePath
# Predicted:  getScopeId
# Ground truth:  suggestScopeByLocation
# Predicted:  getResolveScope
# Ground truth:  getReferenceScope
# Predicted:  visitMaxs
# Ground truth:  visitMaxs
# Predicted:  getCommentTokens
# Ground truth:  getCommentTokens
# Predicted:  getProjectDescriptor
# Ground truth:  getProjectDescriptor
# Predicted:  putIfAbsent
# Ground truth:  putIfAbsent
# Predicted:  isEnabledByDefault
# Ground truth:  isAppendCall
# Predicted:  getSelectedItem
# Ground truth:  getLastNode
# Predicted:  isEnabledByDefault
# Ground truth:  isUnsaved
# Predicted:  setPermanentHeaderComponent
# Ground truth:  setPermanentHeaderComponent
# Predicted:  mouseExited
# Ground truth:  processDragCancel
# Predicted:  update
# Ground truth:  hideNotify
# Predicted:  isEmpty
# Ground truth:  evaluate
# Predicted:  createClassAccessibility
# Ground truth:  getFieldAccessibility
# Predicted:  run
# Ground truth:  empty
# Predicted:  getAllowedValuesFromMagic
# Ground truth:  getAllowedValues
# Predicted:  updateIcon
# Ground truth:  updateIcons
# Predicted:  isEnabledByDefault
# Ground truth:  equals
# Predicted:  removeBreakpoint
# Ground truth:  removeBreakpoint
# Predicted:  getProperty
# Ground truth:  getProperty
# Predicted:  getBackground
# Ground truth:  getBackground
# Predicted:  isEnabledByDefault
# Ground truth:  equals
# Predicted:  getFile
# Ground truth:  getPsiFile
# Predicted:  newMethod
# Ground truth:  main
# Predicted:  getRoot
# Ground truth:  getRoot
# Predicted:  enableInspectionTools
# Ground truth:  enableInspections
# Predicted:  getCommunicationManager
# Ground truth:  getCommunicationManager
# Predicted:  getProfileManager
# Ground truth:  getProfileManager
# Predicted:  isIdSet
# Ground truth:  containsFileId
# Predicted:  getRootType
# Ground truth:  getOrderRootType
# Predicted:  isPhysical
# Ground truth:  shouldFirePhysicalPsiEvents
# Predicted:  setExcluded
# Ground truth:  setExcluded
# Predicted:  foo
# Ground truth:  foo
# Predicted:  clearRelativePath
# Ground truth:  clearRelativePath
# Predicted:  getSerializedSize
# Ground truth:  getSerializedSize
# Predicted:  withoutLibraries
# Ground truth:  withoutLibraries
# Predicted:  setTempFilesPathVisible
# Ground truth:  setTempFilesPathVisible
# Predicted:  actionPerformed
# Ground truth:  moveOffsetAfter
# Predicted:  setParamsMessage
# Ground truth:  setParamsMessage
# Predicted:  update
# Ground truth:  updateAllEnabled
# Predicted:  getDescriptionMarkup
# Ground truth:  getDescriptionMarkup
# Predicted:  newMethod
# Ground truth:  newMethod
# Predicted:  skipTrailingWhite
# Ground truth:  nextWord
# Predicted:  getDefaultRoamingType
# Ground truth:  roamingType
# Predicted:  render
# Ground truth:  customize
# Predicted:  childAdded
# Ground truth:  childRemoved
# Predicted:  setContainingClass
# Ground truth:  addMethod
# Predicted:  getLanguageLevel
# Ground truth:  getLanguageLevel
# Predicted:  updateContextHints
# Ground truth:  updateContextHints
# Predicted:  isSearchDeep
# Ground truth:  isSearchDeep
# Predicted:  getTableCellRendererComponent
# Ground truth:  createBooleanCellRenderer
# Predicted:  getEntry
# Ground truth:  getChild
# Predicted:  setSecondaryActionsIcon
# Ground truth:  setSecondaryActionsIcon
# Predicted:  getValue
# Ground truth:  getValue
# Predicted:  getLineNumber
# Ground truth:  convert
# Predicted:  isApplicable
# Ground truth:  isLanguageExtension
# Predicted:  bulkUpdateFinished
# Ground truth:  notifyListenersOnBulkModeFinished
# Predicted:  isEnabled
# Ground truth:  hasExtension
# Predicted:  layoutEntryPoint
# Ground truth:  getEntryPointRect
# Predicted:  setFramework
# Ground truth:  setFramework
# Predicted:  main
# Ground truth:  main
# Predicted:  isEnabledByDefault
# Ground truth:  isDataExcluded
# Predicted:  update
# Ground truth:  getFont
# Predicted:  createCommonCodeStyleDescriptors
# Ground truth:  collectCommonLanguageProperties
# Predicted:  createAdditionalItems
# Ground truth:  createAdditionalItems
# Predicted:  equals
# Ground truth:  equals
# Predicted:  addAll
# Ground truth:  resetEditorFrom
# Predicted:  isEnabledByDefault
# Ground truth:  shouldSearchInLanguage
# Predicted:  toString
# Ground truth:  toString
# Predicted:  synchronizeTempDirVfs
# Ground truth:  synchronizeTempDirVfs
# Predicted:  getListCellRendererComponent
# Ground truth:  doCopyToClipboardAction
# Predicted:  split
# Ground truth:  closeEditor
# Predicted:  buildMatcher
# Ground truth:  buildPatternMatcher
# Predicted:  getAccessibleRole
# Ground truth:  getAccessibleRole
# Predicted:  getPreferredSize
# Ground truth:  getMainPanelPreferredSize
# Predicted:  getLength
# Ground truth:  getLength
# Predicted:  isLeaf
# Ground truth:  traceWasStarted
# Predicted:  getInstance
# Ground truth:  getInstance
# Predicted:  unlock
# Ground truth:  elementFinished
# Predicted:  visitMethodCallExpression
# Ground truth:  visitMethodCallExpression
# Predicted:  isEnabledByDefault
# Ground truth:  supportsStubs
# Predicted:  getAlternativeText
# Ground truth:  getAlternativeText
# Predicted:  visitMethodCallExpression
# Ground truth:  visitPolyadicExpression
# Predicted:  getAttributes
# Ground truth:  getAttributes
# Predicted:  getIcon
# Ground truth:  getToArrayDescriptor
# Predicted:  isEnabledByDefault
# Ground truth:  tryStatementMayCompleteNormally
# Predicted:  setTarget
# Ground truth:  setTarget
# Predicted:  createOperation
# Ground truth:  createOperation
# Predicted:  getIcon
# Ground truth:  createViewer
# Predicted:  visitClass
# Ground truth:  visitClass
# Predicted:  submit
# Ground truth:  createProcessHandler
# Predicted:  getItemPresentation
# Ground truth:  getPresentation
# Predicted:  equals
# Ground truth:  equals
# Predicted:  isUnboundOutputRoot
# Ground truth:  isRoot
# Predicted:  reachable
# Ground truth:  getUnreachableStatement
# Predicted:  componentResized
# Ground truth:  setIcons
# Predicted:  main
# Ground truth:  example
# Predicted:  clip
# Ground truth:  clip
# Predicted:  setConfigurationIcon
# Ground truth:  updateIcon
# Predicted:  createGroup
# Ground truth:  fillGroupIgnorePopupFlag
# Predicted:  wait
# Ground truth:  wait
# Predicted:  createCompositeNode
# Ground truth:  createCompositeNode
# Predicted:  getContextManager
# Ground truth:  getDebuggerStateManager
# Predicted:  open
# Ground truth:  projectOpened
# Predicted:  visitMethodCallExpression
# Ground truth:  pass
# Predicted:  getPreferredSpan
# Ground truth:  getMinimumSpan
# Predicted:  isTypeApplicable
# Ground truth:  isCompatibleWithOriginalRunConfiguration
# Predicted:  isNonBlockingLoad
# Ground truth:  isNonBlockingLoad
# Predicted:  getContainingFile
# Ground truth:  getContainingFile
# Predicted:  getOptionValue
# Ground truth:  getValue
# Predicted:  xyToOffset
# Ground truth:  viewToModel
# Predicted:  get
# Ground truth:  get
# Predicted:  getInstance
# Ground truth:  getProgressIndicator
# Predicted:  update
# Ground truth:  update
# Predicted:  getXxxx
# Ground truth:  getXxxx
# Predicted:  getPresentableText
# Ground truth:  getPresentableName
# Predicted:  isApplicable
# Ground truth:  isResourceVariable
# Predicted:  main
# Ground truth:  main
# Predicted:  compare
# Ground truth:  compare
# Predicted:  buildVisitor
# Ground truth:  buildVisitor
# Predicted:  isStatic
# Ground truth:  isMovableMember
# Predicted:  reset
# Ground truth:  init
# Predicted:  getKind
# Ground truth:  getPolyadicKind
# Predicted:  mouseMoved
# Ground truth:  mouseMoved
# Predicted:  setComponent
# Ground truth:  setTargetComponent
# Predicted:  isEnabledByDefault
# Ground truth:  canRepresent
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  mirrorOf
# Ground truth:  mirrorOf
# Predicted:  isMandatoryBom
# Ground truth:  isBOMMandatory
# Predicted:  runIntendedWriteActionOnCurrentThread
# Ground truth:  Runnable
# Predicted:  shouldIgnoreInEmptyIndexSuite
# Ground truth:  shouldIgnore
# Predicted:  getMinimumSize
# Ground truth:  getMinimumSize
# Predicted:  isSelected
# Ground truth:  isSelected
# Predicted:  getDefaultFilesToSendProvider
# Ground truth:  getFilesToSendProvider
# Predicted:  selectContent
# Ground truth:  selectContentByContributor
# Predicted:  accept
# Ground truth:  accept
# Predicted:  buildErrorString
# Ground truth:  toString
# Predicted:  restoreBySignature
# Ground truth:  restoreBySignature
# Predicted:  isEnabledByDefault
# Ground truth:  zzCanGrow
# Predicted:  run
# Ground truth:  run
# Predicted:  setShowWithDiffOnly
# Ground truth:  setShowDiffOnly
# Predicted:  getTotalLength
# Ground truth:  getTotalLength
# Predicted:  isInlineFieldThis
# Ground truth:  isInlineThis
# Predicted:  createListItemPresentation
# Ground truth:  getPresentation
# Predicted:  run
# Ground truth:  run
# Predicted:  isSyncScrollEnabled
# Ground truth:  isSyncScrollEnabled
# Predicted:  updateNotificationsPanel
# Ground truth:  updateNotifications
# Predicted:  replaceAll
# Ground truth:  update
# Predicted:  isMethodAcceptable
# Ground truth:  canHaveSiblingSuper
# Predicted:  isEnabledByDefault
# Ground truth:  isVisibilitySupported
# Predicted:  apply
# Ground truth:  apply
# Predicted:  matches
# Ground truth:  matches
# Predicted:  getLastChange
# Ground truth:  getLastChange
# Predicted:  isEnabledByDefault
# Ground truth:  buildQuickFixesOnlyForOnTheFlyErrors
# Predicted:  getNode
# Ground truth:  createFavoriteListNode
# Predicted:  showHighlighter
# Ground truth:  onTimer
# Predicted:  main
# Ground truth:  main
# Predicted:  getName
# Ground truth:  getName
# Predicted:  hasIsGenerated
# Ground truth:  hasMostSigBits
# Predicted:  isRunAsRootViaSudo
# Ground truth:  isRunAsRootViaSudo
# Predicted:  isEquivalentTo
# Ground truth:  areEquivalent
# Predicted:  getHost
# Ground truth:  getHost
# Predicted:  newMethod
# Ground truth:  newMethod
# Predicted:  isPopupVisible
# Ground truth:  isVisible
# Predicted:  applyScheme
# Ground truth:  restoreDefaults
# Predicted:  isEnabledByDefault
# Ground truth:  isSuitablePrimitiveType
# Predicted:  updateText
# Ground truth:  stateChanged
# Predicted:  setTransparencyCHESSBOARDVisible
# Ground truth:  setTransparencyChessboardVisible
# Predicted:  getState
# Ground truth:  writeExternal
# Predicted:  getIcon
# Ground truth:  getNewContentRevision
# Predicted:  onEnvironmentPrepared
# Ground truth:  onEnvironmentPrepared
# Predicted:  getContentRoot
# Ground truth:  DirectoryInfo
# Predicted:  update
# Ground truth:  update
# Predicted:  remove
# Ground truth:  removeExplicitExtension
# Predicted:  rootEntry
# Ground truth:  getRoot
# Predicted:  getScope
# Ground truth:  valueOf
# Predicted:  canClose
# Ground truth:  canClose
# Predicted:  getIcon
# Ground truth:  substituteElementToRename
# Predicted:  getEditingPath
# Ground truth:  getEditingPath
# Predicted:  addImports
# Ground truth:  associate
# Predicted:  compareAttributes
# Ground truth:  attributesEqual
# Predicted:  isTypeOf
# Ground truth:  isMapType
# Predicted:  setupDebugger
# Ground truth:  setupDebugger
# Predicted:  save
# Ground truth:  getState
# Predicted:  set
# Ground truth:  storeCharset
# Predicted:  addListener
# Ground truth:  addFrameworkListener
# Predicted:  logPopupClosed
# Ground truth:  onClosed
# Predicted:  getPresentableName
# Ground truth:  getBundleQName
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  buildFix
# Ground truth:  buildFix
# Predicted:  processCaret
# Ground truth:  appendSearchText
# Predicted:  getPackage
# Ground truth:  getMigrationPackage
# Predicted:  size
# Ground truth:  getSize
# Predicted:  visitMethodCallExpression
# Ground truth:  visitClass
# Predicted:  compareTo
# Ground truth:  compareTo
# Predicted:  scheduleAnimation
# Ground truth:  prepareAnimations
# Predicted:  buildVisitor
# Ground truth:  buildVisitor
# Predicted:  tryExtractJava8Style
# Ground truth:  tryExtract
# Predicted:  isEmpty
# Ground truth:  isEmptyTextVisible
# Predicted:  suppressGuardedExceptions
# Ground truth:  suppressGuardedExceptions
# Predicted:  isAssignableFromRunnableOrCallable
# Ground truth:  isCallableOrRunnable
# Predicted:  addInspectionsReportingProblems
# Ground truth:  reportInspectionsWhichReportedProblems
# Predicted:  run
# Ground truth:  foo
# Predicted:  getMessage
# Ground truth:  toString
# Predicted:  hasIsGenerated
# Ground truth:  hasGlobalOptionsPath
# Predicted:  addPackageEntries
# Ground truth:  fromExternal
# Predicted:  mouseExited
# Ground truth:  mouseExited
# Predicted:  remove
# Ground truth:  invalidate
# Predicted:  addLineIndent
# Ground truth:  getPositionInfo
# Predicted:  waitUntilRefreshed
# Ground truth:  ensureUpToDate
# Predicted:  isEnabled
# Ground truth:  isModified
# Predicted:  hashCode
# Ground truth:  getHashCode
# Predicted:  method
# Ground truth:  method
# Predicted:  main
# Ground truth:  main
# Predicted:  convert
# Ground truth:  getSubSequenceWithHashCode
# Predicted:  newMethod
# Ground truth:  newMethod
# Predicted:  getEvaluationMode
# Ground truth:  getEvaluationMode
# Predicted:  hashCode
# Ground truth:  hashCode
# Predicted:  getImage
# Ground truth:  getIcon
# Predicted:  setBouncing
# Ground truth:  clearAttraction
# Predicted:  isPublic
# Ground truth:  isPublic
# Predicted:  runWithProgress
# Ground truth:  invokeLaterIfNeeded
# Predicted:  setOutputObject
# Ground truth:  setOutputObject
# Predicted:  visitMethodCallExpression
# Ground truth:  showNotify
# Predicted:  setShowDetailsPanel
# Ground truth:  setShowDetailsInPushDialog
# Predicted:  cancel
# Ground truth:  cancel
# Predicted:  buildFix
# Ground truth:  buildFix
# Predicted:  paintComponent
# Ground truth:  executePaint
# Predicted:  update
# Ground truth:  update
# Predicted:  size
# Ground truth:  size
# Predicted:  isSynchronized
# Ground truth:  isGenerated
# Predicted:  getListCellRendererComponent
# Ground truth:  getListCellRendererComponent
# Predicted:  toString
# Ground truth:  toString
# Predicted:  isTransitive
# Ground truth:  isTransitive
# Predicted:  applyFix
# Ground truth:  applyFix
# Predicted:  getCommandForCommand
# Ground truth:  getCompleteCommand
# Predicted:  createModule
# Ground truth:  performAction
# Predicted:  getInstance
# Ground truth:  getInstance
# Predicted:  isEnabledByDefault
# Ground truth:  canUnwrapBlock
# Predicted:  isIgnoredFile
# Ground truth:  calcIgnored
# Predicted:  getComponentAfter
# Ground truth:  getPreferredFocusableComponent
# Predicted:  setOriginInfo
# Ground truth:  setOriginInfo
# Predicted:  isEnabledByDefault
# Ground truth:  isCollapseMethodByDefault
# Predicted:  main
# Ground truth:  main
# Predicted:  m
# Ground truth:  m
# Predicted:  getUrl
# Ground truth:  getOriginalFileUrl
# Predicted:  onClosed
# Ground truth:  endProgress
# Predicted:  readExternal
# Ground truth:  readExternal
# Predicted:  isLeaf
# Ground truth:  contains
# Predicted:  remove
# Ground truth:  remove
# Predicted:  canBeEqual
# Ground truth:  canMergeWith
# Predicted:  getIcon
# Ground truth:  getContentAt
# Predicted:  removeRoot
# Ground truth:  removeExcludedRoot
# Predicted:  isEnabledByDefault
# Ground truth:  needExpandAll
# Predicted:  addModule
# Ground truth:  removeData
# Predicted:  visitMethodCallExpression
# Ground truth:  checkChanges
# Predicted:  applyFix
# Ground truth:  createName
# Predicted:  getOrProvideImage
# Ground truth:  apply
# Predicted:  getInstance
# Ground truth:  getInstance
# Predicted:  update
# Ground truth:  update
# Predicted:  setFieldName
# Ground truth:  setFieldName
# Predicted:  getDelegatedTarget
# Ground truth:  getDelegatedTarget
# Predicted:  clearManifestFiles
# Ground truth:  clear
# Predicted:  getSeparator
# Ground truth:  getSeparator
# Predicted:  markChildChanged
# Ground truth:  integrateIntoExistingChanges
# Predicted:  h
# Ground truth:  h
# Predicted:  startWatching
# Ground truth:  resumeAction
# Predicted:  actionPerformed
# Ground truth:  handleDoubleClickOrEnter
# Predicted:  setTransferable
# Ground truth:  contentChanged
# Predicted:  loadDefaultLiveTemplates
# Ground truth:  loadDefaultLiveTemplates
# Predicted:  commitModel
# Ground truth:  commitModel
# Predicted:  setChildBounds
# Ground truth:  setRelativeBounds
# Predicted:  addDirtyDir
# Ground truth:  addDirtyDirRecursively
# Predicted:  inputChanged
# Ground truth:  setInputEvent
# Predicted:  getTextLength
# Ground truth:  foo3
# Predicted:  getType
# Ground truth:  nearestAccessibleType
# Predicted:  setCompactDirectories
# Ground truth:  setCompactDirectories
# Predicted:  getCustomNode
# Ground truth:  isCustomNode
# Predicted:  getScope
# Ground truth:  getResolveScope
# Predicted:  setDataPack
# Ground truth:  dataPackArrived
# Predicted:  mouseClicked
# Ground truth:  mouseClicked
# Predicted:  addElements
# Ground truth:  applyFix
# Predicted:  getWindowSize
# Ground truth:  showValuePopup
# Predicted:  contains
# Ground truth:  hasEntry
# Predicted:  register
# Ground truth:  setupListeners
# Predicted:  accept
# Ground truth:  createOrGet
# Predicted:  getSerializedSize
# Ground truth:  getSerializedSize
# Predicted:  writeExternal
# Ground truth:  writeExternal
# Predicted:  getVariable
# Ground truth:  resolveOrderFast
# Predicted:  getVirtualFile
# Ground truth:  getVirtualFile
# Predicted:  createFrameListRenderer
# Ground truth:  createItemComponent
# Predicted:  mark
# Ground truth:  printOn
# Predicted:  valueChanged
# Ground truth:  valueChanged
# Predicted:  getSubstitutor
# Ground truth:  getSubstitutor
# Predicted:  size
# Ground truth:  charAt
# Predicted:  isReferenceToClass
# Ground truth:  isStaticallyReferenced
# Predicted:  isEnabledByDefault
# Ground truth:  isArrayLookup
# Predicted:  isEnabledByDefault
# Ground truth:  withField
# Predicted:  isEnabledByDefault
# Ground truth:  isUseFileNestingRules
# Predicted:  toString
# Ground truth:  toString
# Predicted:  getContainingClass
# Ground truth:  getParent
# Predicted:  getHandler
# Ground truth:  getPushDownHandler
# Predicted:  visitReturnStatement
# Ground truth:  registerFixesForExpressionStatement
# Predicted:  getProject
# Ground truth:  getProject
# Predicted:  getRegisteredBreakpoint
# Ground truth:  getBreakpointPresentation
# Predicted:  setFamily
# Ground truth:  setFamily
# Predicted:  isEnabledByDefault
# Ground truth:  attributeListsEqual
# Predicted:  getInspection
# Ground truth:  getInspection
# Predicted:  getDetectorById
# Ground truth:  getDetectorById
# Predicted:  getInstance
# Ground truth:  getInstance
# Predicted:  clear
# Ground truth:  resetState
# Predicted:  run
# Ground truth:  run
# Predicted:  visitMethodCallExpression
# Ground truth:  startMonitor
# Predicted:  actionPerformed
# Ground truth:  invoke
# Predicted:  canSelect
# Ground truth:  canSelect
# Predicted:  isOperational
# Ground truth:  isExpressionStatementExpression
# Predicted:  show
# Ground truth:  hideBalloon
# Predicted:  getHtmlWithFonts
# Ground truth:  getHtmlWithFonts
# Predicted:  main
# Ground truth:  main
# Predicted:  set
# Ground truth:  getLogicalBounds
# Predicted:  setShowInspectPlace
# Ground truth:  setShowInspectionWidget
# Predicted:  getState
# Ground truth:  s
# Predicted:  setTree
# Ground truth:  updateContainer
# Predicted:  computeCastTo
# Ground truth:  computeCastTo
# Predicted:  getSandboxHome
# Ground truth:  getSandboxHome
# Predicted:  getProjectDescriptor
# Ground truth:  getProjectDescriptor
# Predicted:  visitReferenceExpression
# Ground truth:  visitLambdaExpression
# Predicted:  getCurrentIndicators
# Ground truth:  getCurrentIndicator
# Predicted:  getIcon
# Ground truth:  buildFix
# Predicted:  main
# Ground truth:  main
# Predicted:  isEquivalent
# Ground truth:  tryConsumeIteration
# Predicted:  isAccessible
# Ground truth:  canBeCreatedInQualifiedNew
# Predicted:  set
# Ground truth:  getCanonicalText
# Predicted:  showForComponent
# Ground truth:  maybeShowFor
# Predicted:  isPaintSelection
# Ground truth:  isPaintSelection
# Predicted:  visitMethodCallExpression
# Ground truth:  addProblemElement
# Predicted:  isEAP
# Ground truth:  isEAP
# Predicted:  visitMethodCallExpression
# Ground truth:  invoke
# Predicted:  fileMoved
# Ground truth:  fileCreated
# Predicted:  checkFontSize
# Ground truth:  checkFontSize
# Predicted:  run
# Ground truth:  pauseExecution
# Predicted:  getIcon
# Ground truth:  load
# Predicted:  deserialize
# Ground truth:  deserialize
# Predicted:  visitAnnotation
# Ground truth:  visitAnnotation
# Predicted:  getWhitespaceCharacter
# Ground truth:  whitespaceCharacter
# Predicted:  isSearchMatch
# Ground truth:  isSearchMatch
# Predicted:  getClassReference
# Ground truth:  getClassReference
# Predicted:  setSelectedItem
# Ground truth:  setSelectedChar
# Predicted:  getRootElement
# Ground truth:  getComponent
# Predicted:  dispose
# Ground truth:  doPause
# Predicted:  getInlaysHeight
# Ground truth:  getInlaysHeight
# Predicted:  main
# Ground truth:  example
# Predicted:  matchingDegree
# Ground truth:  matchingDegree
# Predicted:  isVarArgsMethod
# Ground truth:  isVarArgs
# Predicted:  getIcon
# Ground truth:  toNode
# Predicted:  update
# Ground truth:  restoreInGrid
# Predicted:  applyFix
# Ground truth:  applyFix
# Predicted:  renderElement
# Ground truth:  update
# Predicted:  actionPerformed
# Ground truth:  showStandaloneDiff
# Predicted:  isLookupPattern
# Ground truth:  isSelectedByTyping
# Predicted:  visitMethodCallExpression
# Ground truth:  chooseFileAndExport
# Predicted:  visitAntDomProperty
# Ground truth:  visitProperty
# Predicted:  create RWLockProtectedPage
# Ground truth:  createPage
# Predicted:  findRootClass
# Ground truth:  findJarByClass
# Predicted:  getIndexOfConcreteDirection
# Ground truth:  explicitDirection
# Predicted:  onSuccess
# Ground truth:  cancelDownloading
# Predicted:  isPlaceholder
# Ground truth:  isCollapsedByDefault
# Predicted:  switchToFLUSH
# Ground truth:  and
# Predicted:  getInstance
# Ground truth:  getInstance
# Predicted:  getIsRefreshable
# Ground truth:  getIsRefreshable
# Predicted:  visitMethodCallExpression
# Ground truth:  replaceMergeableImplicitIf
# Predicted:  getTextLength
# Ground truth:  convertModuleName
# Predicted:  getComponent
# Ground truth:  getComponent
# Predicted:  setSelected
# Ground truth:  setToBeShown
# Predicted:  invokeLater
# Ground truth:  invokeLater
# Predicted:  canMove
# Ground truth:  isCutEnabled
# Predicted:  main
# Ground truth:  extracted
# Predicted:  getHint
# Ground truth:  getHint
# Predicted:  isCountFilterEnabled
# Ground truth:  isCountFilterEnabled
# Predicted:  close
# Ground truth:  close
# Predicted:  isSelected
# Ground truth:  supportsOverloadSwitching
# Predicted:  createMouseWheelScroll
# Ground truth:  create
# Predicted:  actionPerformed
# Ground truth:  focusLost
# Predicted:  checkResidence
# Ground truth:  checkResidence
# Predicted:  notifyInfo
# Ground truth:  notifySuccess
# Predicted:  fileClosed
# Ground truth:  profilesInitialized
# Predicted:  visitAnnotation
# Ground truth:  visitEnd
# Predicted:  setSelected
# Ground truth:  setSelected
# Predicted:  setSelected
# Ground truth:  registerJavacFileData
# Predicted:  getState
# Ground truth:  getState
# Predicted:  processContextHints
# Ground truth:  processContextHints
# Predicted:  getText
# Ground truth:  replace
# Predicted:  textChanged
# Ground truth:  createCenterPanel
# Predicted:  getMethodCallExpression
# Ground truth:  getDirectParentMethod
# Predicted:  buildFix
# Ground truth:  buildFix
# Predicted:  getShortName
# Ground truth:  getUnixMode
# Predicted:  getIcon
# Ground truth:  getProjectCompileScope
# Predicted:  merge
# Ground truth:  markWhitespaceForReformat
# Predicted:  requestFocusInProject
# Ground truth:  requestFocusWithFallback
# Predicted:  addTarget
# Ground truth:  addTargets
# Predicted:  getHandler
# Ground truth:  getHandler
# Predicted:  getI
# Ground truth:  findFirst
# Predicted:  getIcon
# Ground truth:  getTableCellEditorComponent
# Predicted:  getIcon
# Ground truth:  getRBrace
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  main
# Ground truth:  main
# Predicted:  removePersistentEntry
# Ground truth:  validateEntryPoints
# Predicted:  updateSearchFurtherBtns
# Ground truth:  updateInEdt
# Predicted:  shouldBeRefreshed
# Ground truth:  shouldBeRefreshed
# Predicted:  getIndex
# Ground truth:  getOriginal
# Predicted:  getIcon
# Ground truth:  findTagName
# Predicted:  removeListener
# Ground truth:  removeElementsMarkListener
# Predicted:  foo
# Ground truth:  run
# Predicted:  isTargetWithClearedOutput
# Ground truth:  isTargetOutputCleared
# Predicted:  getContextModule
# Ground truth:  getModule
# Predicted:  remove
# Ground truth:  removeFrom
# Predicted:  getContent
# Ground truth:  createDiffContent
# Predicted:  toString
# Ground truth:  toString
# Predicted:  getArtifactsStructureConfigurable
# Ground truth:  getArtifactsStructureConfigurable
# Predicted:  isModified
# Ground truth:  isModified
# Predicted:  dispose
# Ground truth:  dispose
# Predicted:  getIcon
# Ground truth:  createLookupElement
# Predicted:  run
# Ground truth:  run
# Predicted:  run
# Ground truth:  run
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  isDeleted
# Ground truth:  isStaleIdDeletion
# Predicted:  isFlattenPackages
# Ground truth:  isFlattenPackages
# Predicted:  reduce
# Ground truth:  reduceClasses
# Predicted:  getUnimportantLineCharCount
# Ground truth:  getUnimportantLineCharCount
# Predicted:  hasKind
# Ground truth:  hasProblemLocationOffset
# Predicted:  size
# Ground truth:  sizeOf
# Predicted:  createDefaultDeploymentConfiguration
# Ground truth:  createDeploymentConfiguration
# Predicted:  isEnabledByDefault
# Ground truth:  startInWriteAction
# Predicted:  getVcsName
# Ground truth:  getVcsName
# Predicted:  firePropertyExpanded
# Ground truth:  notifyPropertyExpanded
# Predicted:  withParameters
# Ground truth:  addParameters
# Predicted:  perform
# Ground truth:  perform
# Predicted:  getTypeParameterText
# Ground truth:  serialize
# Predicted:  setCollectedEvents
# Ground truth:  before
# Predicted:  set
# Ground truth:  remove
# Predicted:  createComponent
# Ground truth:  createComponent
# Predicted:  getHome
# Ground truth:  getHomeValue
# Predicted:  textChanged
# Ground truth:  documentChanged
# Predicted:  buildFix
# Ground truth:  buildFix
# Predicted:  getBufferPosition
# Ground truth:  getBufferPosition
# Predicted:  visitMethodCallExpression
# Ground truth:  invokeLater
# Predicted:  getDisplayName
# Ground truth:  getDisplayName
# Predicted:  newMethod
# Ground truth:  newMethod
# Predicted:  setSelectedIndex
# Ground truth:  setSelectedIndex
# Predicted:  visitMethodCallExpression
# Ground truth:  visitLocalVariable
# Predicted:  isEnabledByDefault
# Ground truth:  toolWindowIsNotEmpty
# Predicted:  equals
# Ground truth:  isStandardEqualsMethod
# Predicted:  hashCode
# Ground truth:  hashCode
# Predicted:  getStartOffset
# Ground truth:  compareTo
# Predicted:  getIcon
# Ground truth:  getChildText
# Predicted:  update
# Ground truth:  processPresentation
# Predicted:  getMerger
# Ground truth:  getMerger
# Predicted:  getRenderer
# Ground truth:  getRenderer
# Predicted:  set
# Ground truth:  editExternalAnnotation
# Predicted:  stopEditing
# Ground truth:  stopEditing
# Predicted:  visitMethodCallExpression
# Ground truth:  paintSelectionOnFirstSoftWrapLineIfNecessary
# Predicted:  doAction
# Ground truth:  actionPerformed
# Predicted:  getTargetElement
# Ground truth:  resolveClassCreatedByFunction
# Predicted:  mouseReleased
# Ground truth:  fileCopied
# Predicted:  meth
# Ground truth:  meth
# Predicted:  findLeftLParen
# Ground truth:  findLeftmostLParen
# Predicted:  getLeftIndent
# Ground truth:  getControlOffset
# Predicted:  actionPerformed
# Ground truth:  actionPerformed
# Predicted:  setLength
# Ground truth:  setLength
# Predicted:  next
# Ground truth:  next
# Predicted:  buildInternalVisitor
# Ground truth:  visitQualifiedReferenceExpression
# Predicted:  dispose
# Ground truth:  disable
# Predicted:  getLongIndex
# Ground truth:  getLongIndex
# Predicted:  clearFrameVariants
# Ground truth:  clearVariants
# Predicted:  addListener
# Ground truth:  addListener
# Predicted:  isNull
# Ground truth:  isNotNull
# Predicted:  addAnchorElement
# Ground truth:  applyFix
# Predicted:  isInclusion
# Ground truth:  isIgnored
# Predicted:  getIcon
# Ground truth:  getTreeView
# Predicted:  getState
# Ground truth:  archive
# Predicted:  getRepository
# Ground truth:  getRepository
# Predicted:  visitMethodCallExpression
# Ground truth:  visitMethod
# Predicted:  drawString
# Ground truth:  drawString
# Predicted:  createLibrary
# Ground truth:  addSupport
# Predicted:  visitRegExpNumber
# Ground truth:  visitRegExpNumber
# Predicted:  advance
# Ground truth:  handleTokenNotFound
# Predicted:  createModel
# Ground truth:  copy
# Predicted:  getTextLength
# Ground truth:  getNavigationElement
# Predicted:  update
# Ground truth:  setVisible
# Predicted:  writeExternal
# Ground truth:  writeExternal
# Predicted:  isEnabledByDefault
# Ground truth:  isTargetedToProduct
# Predicted:  getVisibleRange
# Ground truth:  getVisibleInterval
# Predicted:  getOwner
# Ground truth:  getOwner
# Predicted:  isPaused
# Ground truth:  isEnabled
# Predicted:  getArgFile
# Ground truth:  isArgFile
# Predicted:  findElementByPath
# Ground truth:  getContentRoot
# Predicted:  visitMethodCallExpression
# Ground truth:  visitMethodCallExpression
# Predicted:  main
# Ground truth:  main
# Predicted:  startWhenFrameActive
# Ground truth:  runOnFrame
# Predicted:  appendLeaf
# Ground truth:  visitElement
# ...
# Predicted:  isOnEdt
# Ground truth:  runInDispatchThread
# Predicted:  append
# Ground truth:  append
# Predicted:  toInt
# Ground truth:  packValues
# Predicted:  parameterUsageMethod
# Ground truth:  parameterUsageMethod
# Predicted:  getFi
# Ground truth:  getStrings
# Predicted:  visitElement
# Ground truth:  visitAnnotationParameter
# Predicted:  addSkippingWhitespaceFilters
# Ground truth:  registerFilterToSkipMarkingAffectedFileDirty
# Predicted:  getInspection
# Ground truth:  getInspection
# Predicted:  getTrackingTypeAt
# Ground truth:  getTrackingType
# Predicted:  isEnabledByDefault
# Ground truth:  isNullObject
# Predicted:  convertTime
# Ground truth:  getDelay
# Predicted:  getIcon
# Ground truth:  getDefaultLightLaf
# Predicted:  findDeclaredAttributeValue
# Ground truth:  findDeclaredAttributeValue
# Predicted:  getColumnCount
# Ground truth:  getColumnCount
# Predicted:  getBorderInsets
# Ground truth:  getTitleInsets
# Predicted:  actionPerformed
# Ground truth:  insideReadAction
# Predicted:  getState
# Ground truth:  getState
# Predicted:  getParent
# Ground truth:  getParent
# Predicted:  create
# Ground truth:  build
# Predicted:  visitClassType
# Ground truth:  visitClassType
# Predicted:  changeAttributesInBatch
# Ground truth:  changeAttributesInBatch
# Predicted:  visitMethodCallExpression
# Ground truth:  addSearchResultsIntoEnd
# Predicted:  setBuildOnMake
# Ground truth:  setBuildOnMake
# Predicted:  findReferenceAtCaret
# Ground truth:  findReferenceAtCaret
# Predicted:  generateDefaultFontFamilyRule
# Ground truth:  appendStartTags
# Predicted:  isFrameworkApplicable
# Ground truth:  isFrameworkAvailable
# Predicted:  getVariableParent
# Ground truth:  getRoot
# Predicted:  invoke
# Ground truth:  applyFix
# Predicted:  getPrefixLength
# Ground truth:  hostToInjectedUnescaped
# Predicted:  checkRoot
# Ground truth:  visit
# Predicted:  addImpl
# Ground truth:  addImpl
# Predicted:  buildVisitor
# Ground truth:  visitMethodCallExpression
# Predicted:  foo
# Ground truth:  foo
# Predicted:  getDefaultValue
# Ground truth:  getDefaultValue
# Predicted:  assertEqual
# Ground truth:  assertPair
# Predicted:  applyChanges
# Ground truth:  applyChanges
# Predicted:  getIcon
# Ground truth:  getPreviousStatement
# Predicted:  appendIndent
# Ground truth:  buildMultiText
# Predicted:  setCurrentScope
# Ground truth:  setCurrentScope
# Predicted:  getSignatureBackedByPsi
# Ground truth:  getSignature
# Predicted:  writeExternal
# Ground truth:  writeExternal
# Predicted:  init
# Ground truth:  reloadTree
# Predicted:  actionPerformed
# Ground truth:  run
# Predicted:  isEnabledByDefault
# Ground truth:  startInWriteAction
# Predicted:  visitReferenceElement
# Ground truth:  makeContentReachable
# Predicted:  hashCode
# Ground truth:  getHashCodeStepCode
# Predicted:  getId
# Ground truth:  getId
# Predicted:  isStaticallyImported
# Ground truth:  isAlreadyStaticallyImported
# Predicted:  isInvertWithinConstraint
# Ground truth:  isInvertWithinConstraint
# Predicted:  activateBuildToolWindowOnFailure
# Ground truth:  dontReportRefreshErrors
# Predicted:  getChildRole
# Ground truth:  getChildRole
# Predicted:  visitTypeCastExpression
# Ground truth:  addSecondCompletionVariants
# Predicted:  getProperties
# Ground truth:  setProperties
# Predicted:  isPreview
# Ground truth:  isPreview
# Predicted:  run
# Ground truth:  extracted
# Predicted:  getTextLength
# Ground truth:  applyHeavyFilter
# Predicted:  doExecute
# Ground truth:  beforeDocumentChange
# Predicted:  getDocumentModel
# Ground truth:  getDocumentModel
# Predicted:  contains
# Ground truth:  contains
# Predicted:  update
# Ground truth:  defaultUpdate
# Predicted:  addSdkFailedHandler
# Ground truth:  tryRegisterSdkDownloadFailureHandler
# Predicted:  isEnabledForCaret
# Ground truth:  isEnabledForCaret
# Predicted:  isEnabledByDefault
# Ground truth:  b
# Predicted:  toInt
# Ground truth:  scale
# Predicted:  isInvert
# Ground truth:  isInverted
# Predicted:  getValue
# Ground truth:  copyOperation
# Predicted:  getHighlightRange
# Ground truth:  getHighlightRange
# Predicted:  collectRowChildren
# Ground truth:  getSelection
# Predicted:  waitForUsages
# Ground truth:  waitForUsages
# Predicted:  reset
# Ground truth:  reset
# Predicted:  patchFindNext
# Ground truth:  getFindNextModel
# Predicted:  hashCode
# Ground truth:  hashCode
# Predicted:  getHighlightFile
# Ground truth:  getHighlightFile
# Predicted:  filePathsDirty
# Ground truth:  fileDirty
# Predicted:  contains
# Ground truth:  contains
# Predicted:  getId
# Ground truth:  getId
# Predicted:  getFoo
# Ground truth:  getFoo
# Predicted:  getPreviousCodeProcessor
# Ground truth:  setCollectInfo
# Predicted:  getJavacOptionsGroup
# Ground truth:  getJigsawOptions
# Predicted:  isCustomScope
# Ground truth:  isCustomScope
# Predicted:  getColor
# Ground truth:  getColor
# Predicted:  getFilter
# Ground truth:  getFilter
# Predicted:  update
# Ground truth:  updatePreviewVisibility
# Predicted:  createDescriptorImpl
# Ground truth:  createDescriptorImpl
# Predicted:  reportDeletionProblem
# Ground truth:  reportProblems
# Predicted:  requestFocus
# Ground truth:  select
# Predicted:  g
# Ground truth:  g
# Predicted:  rootChanged
# Ground truth:  rootChanged
# Predicted:  getTreeModel
# Ground truth:  buildTreeModel
# Predicted:  getIcon
# Ground truth:  getModuleScope
# Predicted:  afterInsert
# Ground truth:  changedUpdateImpl
# Predicted:  visitMethodCallExpression
# Ground truth:  applyFix
# Predicted:  totalRetriedAttempts
# Ground truth:  totalRetriedAttempts
# Predicted:  isAvailable
# Ground truth:  execute
# Predicted:  buildVisitor
# Ground truth:  buildVisitor
# Predicted:  isRemoteProcessIdleTtlInMs
# Ground truth:  getRemoteProcessIdleTtlInMs
# Predicted:  isEnabled
# Ground truth:  canAutohideOn
# Predicted:  getRowCount
# Ground truth:  getModelRowCount
# Predicted:  apply
# Ground truth:  initValues
# Predicted:  getRangeSet
# Ground truth:  getDefiniteRange
# Predicted:  disableTemplate
# Ground truth:  loadState
# Predicted:  isModified
# Ground truth:  isSelected
# Predicted:  printOutputFile
# Ground truth:  flushOutputFile
# Predicted:  isEnabledByDefault
# Ground truth:  supportsCustomCreateUI
# Predicted:  getNavigator
# Ground truth:  getNavigator
# Predicted:  createCenterPanel
# Ground truth:  getComponent
# Predicted:  getId
# Ground truth:  getId
# Predicted:  customizeListRendererComponent
# Ground truth:  getListCellRendererComponent
# Predicted:  reset
# Ground truth:  setSelectedItem
# Predicted:  add
# Ground truth:  deleteChildInternal
# Predicted:  getAccessibleContext
# Ground truth:  getElement
# Predicted:  stopProcess
# Ground truth:  stopDaemon
# Predicted:  getLogicalLogicalPosition
# Ground truth:  getNext
# Predicted:  isSelected
# Ground truth:  isPassed
# Predicted:  visitMethodCallExpression
# Ground truth:  selectionChanged
# Predicted:  getIndent
# Ground truth:  getIndent
# Predicted:  serialize
# Ground truth:  serialize
# Predicted:  setProblemBeginOffset
# Ground truth:  setProblemBeginOffset
# Predicted:  createDescriptor
# Ground truth:  createIfInaccessible
# Predicted:  addContent
# Ground truth:  addContent
# Predicted:  update
# Ground truth:  startDrag
# Predicted:  visitMethodCallExpression
# Ground truth:  visitInnerClass
# Predicted:  createNonExistingFileNavigationElement
# Ground truth:  createForNonExistingFile
# Predicted:  hashCode
# Ground truth:  hashCode
# Predicted:  parseDouble
# Ground truth:  parseDouble
# Predicted:  getModuleText
# Ground truth:  forModule
# Predicted:  findLibraryOrderEntry
# Ground truth:  findLibraryOrderEntry
# Predicted:  performAction
# Ground truth:  executeWriteAction
# Predicted:  isEnabledByDefault
# Ground truth:  isStaticsScopeCorrect
# Predicted:  loadHelpFile
# Ground truth:  getMainDocumentation
# Predicted:  selectWordAtCaret
# Ground truth:  selectWordAtCaret
# Predicted:  findAttributeValue
# Ground truth:  findAttributeValue
# Predicted:  accept
# Ground truth:  accept
# Predicted:  isConstructor
# Ground truth:  isAccepted
# Predicted:  getRowCount
# Ground truth:  getElementCount
# Predicted:  getPrevSibling
# Ground truth:  getPrevSibling
# Predicted:  withSize
# Ground truth:  withRandomAttributeBytes
# Predicted:  getScope
# Ground truth:  toSearchScope
# Predicted:  addContentEntry
# Ground truth:  init
# Predicted:  registerEclipseLinkedVarPath
# Ground truth:  registerEclipseLinkedVarPath
# Predicted:  isExtendToContext
# Ground truth:  isReformatWithContext
# Predicted:  generateIndentWhitespace
# Ground truth:  getLineIndent
# Predicted:  isEnabledByDefault
# Ground truth:  isImplicitRead
# Predicted:  addListener
# Ground truth:  addCommandListener
# Predicted:  setVisitedColor
# Ground truth:  setVisitedColor
# Predicted:  visitMethodCallExpression
# Ground truth:  run
# Predicted:  getStartOffset
# Ground truth:  compare
# Predicted:  isEquivalent
# Ground truth:  typesAreEquivalent
# Predicted:  forEachVariableType
# Ground truth:  forRecordedVariableTypes
# Predicted:  clear
# Ground truth:  collectTreePaths
# Predicted:  isFileSelectable
# Ground truth:  createProfilesIniChooserDescriptor
# Predicted:  startMarker
# Ground truth:  setMarker
# Predicted:  isEnabledByDefault
# Ground truth:  isSoft
# Predicted:  isInSourceContent
# Ground truth:  isCovered
# Predicted:  createNewScheme
# Ground truth:  exportProjectScheme
# Predicted:  getCompileMessage
# Ground truth:  getMessage
# Predicted:  getSessionComponent
# Ground truth:  get
# Predicted:  addWhiteSpace
# Ground truth:  addElementBeforeAnchor
# Predicted:  create
# Ground truth:  zip
# Predicted:  isValidFor
# Ground truth:  isValidFor
# Predicted:  selectItem
# Ground truth:  selectAll
# Predicted:  setRetina
# Ground truth:  isRetina
# Predicted:  addBackground
# Ground truth:  processBackground
# Predicted:  getExpectedType
# Ground truth:  findType
# Predicted:  createNode
# Ground truth:  withPopupAdvertisement
# Predicted:  buildFix
# Ground truth:  buildFix
# Predicted:  visitMethodCallExpression
# Ground truth:  addFileNamePattern
# Predicted:  addConfiguration
# Ground truth:  actionPerformed
# Predicted:  clear
# Ground truth:  clear
# Predicted:  removeVisibility
# Ground truth:  removeVisibilityIfNeeded
# Predicted:  getLanguageLevel
# Ground truth:  getLanguageLevel
# Predicted:  apply
# Ground truth:  applyLayoutSettings
# Predicted:  applyFix
# Ground truth:  applyFix
# Predicted:  fromOffset
# Ground truth:  getVisualLineInfo
# Predicted:  queueNext
# Ground truth:  doPerformChildrenGuidance
# Predicted:  getIcon
# Ground truth:  getChangedScopeAndSeverityEvent
# Predicted:  update
# Ground truth:  update
# Predicted:  visitGuardExpression
# Ground truth:  reportUnreachableSwitchBranches
# Predicted:  main
# Ground truth:  main
# Predicted:  getPreferredSize
# Ground truth:  getPreferredSize
# Predicted:  treeNodesChanged
# Ground truth:  eventProcessed
# Predicted:  getParentFile
# Ground truth:  getProjectRepresentationName
# Predicted:  createLibraryTableDescriptor
# Ground truth:  createDescriptor
# Predicted:  getPostponedTimeMillis
# Ground truth:  getFastLoadingTimeMillis
# Predicted:  createFile
# Ground truth:  fun
# Predicted:  setText
# Ground truth:  setErrorStripeTooltip
# Predicted:  hashCode
# Ground truth:  hashCode
# Predicted:  addDependency
# Ground truth:  addDependency
# Predicted:  isNAMEDGroup
# Ground truth:  supportsNamedGroupSyntax
# Predicted:  getCondition
# Ground truth:  getCondition
# Predicted:  visitClass
# Ground truth:  setMonospacedOnly
# Predicted:  processFiles
# Ground truth:  processClassPathItems
# Predicted:  isInfoOf
# Ground truth:  matches
# Predicted:  addEtalon
# Ground truth:  notTooManyFalsePositivesInIndexLookups
# Predicted:  getSearchCriteriaEdit
# Ground truth:  getPreferredFocusedComponent
# Predicted:  getContainingExpression
# Ground truth:  getLoopForLoopCondition
# Predicted:  getTextAttributesKey
# Ground truth:  getTextAttributesKey
# Predicted:  getPresentableUrl
# Ground truth:  getRelativePath
# Predicted:  visitAnnotation
# Ground truth:  actionPerformed
# Predicted:  addFailed
# Ground truth:  updateFailedState
# Predicted:  isEnabledByDefault
# Ground truth:  isSingleParameterInfo
# Predicted:  createReferenceType
# Ground truth:  createInterfaceType
# Predicted:  getEndOffsetUpperEstimate
# Ground truth:  getEndOffsetUpperEstimate
# Predicted:  buildVisitor
# Ground truth:  buildVisitor
# Predicted:  calculateResult
# Ground truth:  calculateResult
# Predicted:  mouseMoved
# Ground truth:  mouseMoved
# Predicted:  visitVariable
# Ground truth:  visitVariable
# Predicted:  getShortPath
# Ground truth:  getShortPath
# Predicted:  visitMethodCallExpression
# Ground truth:  checkSetterNeeded
# Predicted:  createFormBuilder
# Ground truth:  createFormBuilder
# Predicted:  setExternalSystemIdInInternalStorage
# Ground truth:  setExternalSystemIdInInternalStorage
# Predicted:  getThrowable
# Ground truth:  getThrowable
# Predicted:  getTextLength
# Ground truth:  addGroupOfTargets
# Predicted:  visitMethodCallExpression
# Ground truth:  addFileToProcess
# Predicted:  actionPerformed
# Ground truth:  update
# Predicted:  isEnabledByDefault
# Ground truth:  typeIsConcreteClass
# Predicted:  visitBreakStatement
# Ground truth:  moveToBreaks
# Predicted:  equals
# Ground truth:  equals
# Predicted:  isAnchorVisible
# Ground truth:  isHorizontal
# Predicted:  addFieldToClasses
# Ground truth:  addConstantsFromReferencedClassesInSwitch
# Predicted:  r
# Ground truth:  r
# Predicted:  close
# Ground truth:  actionPerformed
# Predicted:  getWidth
# Ground truth:  getColorWidth
# Predicted:  getLineStart
# Ground truth:  getLineStart
# Predicted:  addLibrary
# Ground truth:  onLibraryAdded
# Predicted:  equals
# Ground truth:  equals
# Predicted:  isEnabledByDefault
# Ground truth:  expressionHasTypeOrSubtype
# Predicted:  getMyT
# Ground truth:  getMyT
# Predicted:  visitMethodCallExpression
# Ground truth:  checkAccessStaticMemberViaInstanceReference
# Predicted:  getPreferredFocusedComponent
# Ground truth:  getComponent
# Predicted:  reset
# Ground truth:  clear
# Predicted:  requestUpdate
# Ground truth:  revalidate
# Predicted:  setFontSize
# Ground truth:  setFontSize
# Predicted:  hashCode
# Ground truth:  hashCode
# Predicted:  equals
# Ground truth:  equals
# Predicted:  getGroup
# Ground truth:  getGroup
# Predicted:  update
# Ground truth:  update
# Predicted:  meth
# Ground truth:  run
# Predicted:  buildVisitor
# Ground truth:  buildVisitor
# Predicted:  createDescriptor
# Ground truth:  findConversionForVariableReference
# Predicted:  getInspection
# Ground truth:  getInspection
# Predicted:  fireFileMoved
# Ground truth:  fireFileMoved
# Predicted:  force
# Ground truth:  force
# Predicted:  compileOnly
# Ground truth:  compileOnly
# Predicted:  clearModel
# Ground truth:  dispose
# Predicted:  getClassReference
# Ground truth:  getClassOfDefaultConstructorFunction
# Predicted:  isResolvedBySecondSearch
# Ground truth:  isResolvedBySecondSearch
# Predicted:  hashCode
# Ground truth:  hashCode
# Predicted:  getPreferredSize
# Ground truth:  getPreferredSize
# Predicted:  isEnabledByDefault
# Ground truth:  hasFailContract
# Predicted:  addUsages
# Ground truth:  fillUsages
# Predicted:  applyFix
# Ground truth:  fixLeftAndBothChangeCase
# Predicted:  isEmpty
# Ground truth:  isEmpty
# Predicted:  run
# Ground truth:  actionPerformed
# Predicted:  isValid
# Ground truth:  isAvailable
# Predicted:  removeConfiguration
# Ground truth:  removeConfiguration
# Predicted:  hashCode
# Ground truth:  hashCode
# Predicted:  setCustomSettings
# Ground truth:  addCustomSettings
# Predicted:  visitMethodCallExpression
# Ground truth:  applyFix
# Predicted:  visitMethodCallExpression
# Ground truth:  showPopup
# Predicted:  getLeftContract
# Ground truth:  getCondition
# Predicted:  getReturnType
# Ground truth:  getReturnTypeParameterNotMentionedPreviously
# Predicted:  getFallbackBundleName
# Ground truth:  getFallbackBundleName
# Predicted:  getRow
# Ground truth:  refreshRow
# Predicted:  getWeight
# Ground truth:  getWeight
# Predicted:  getIcon
# Ground truth:  getTagName
# Predicted:  getSourceScope
# Ground truth:  getSourceScope
# Predicted:  newMethod
# Ground truth:  newMethod
# Predicted:  isEnabledByDefault
# Ground truth:  canBeReusedBy
# Predicted:  canNavigateToSource
# Ground truth:  canNavigateToSource
# Predicted:  check
# Ground truth:  checkForProblems
# Predicted:  getAnchor
# Ground truth:  getAnchor
# Predicted:  getFirstElement
# Ground truth:  getChosenElement
# Predicted:  getClass
# Ground truth:  extractClass
# Predicted:  isNonCancelableSection
# Ground truth:  isCancelable
# Predicted:  visitMethodCallExpression
# Ground truth:  buildVisitor
# Hard score:  0.3815667096696769
# Soft score:  0.5165091046805851
# Rouge score:  {'rouge1': 0.5482718569719829, 'rouge2': 0.34525199885820806, 'rougeL': 0.5478022278673956, 'rougeLsum': 0.547840018924667}

# %% [markdown]
# Evaluate the original model

# %%
model_input = [{"input": "Generate a name for the method having the following body: "+example['body'], "label": example['name']} for example in methods_dataset['test']]
predictions_orig, gt = predict_all(original_model, model_input, tokenizer)
# Out:
# 0/33331
# 1000/33331
# 2000/33331
# 3000/33331
# 4000/33331
# 5000/33331
# 6000/33331
# 7000/33331
# 8000/33331
# 9000/33331
# 10000/33331
# 11000/33331
# 12000/33331
# 13000/33331
# 14000/33331
# 15000/33331
# 16000/33331
# 17000/33331
# 18000/33331
# 19000/33331
# 20000/33331
# 21000/33331
# 22000/33331
# 23000/33331
# 24000/33331
# 25000/33331
# 26000/33331
# 27000/33331
# 28000/33331
# 29000/33331
# 30000/33331
# 31000/33331
# 32000/33331
# 33000/33331

# %%
evaluate_predictions(predictions_orig, gt)
# Out:
# Datele de ieșire de afișat au fost trunchiate la ultimele 5000 linii.
# Predicted:  method
# Ground truth:  isTabbingModeAvailable
# Predicted:  function
# Ground truth:  getClasspathEntry
# Predicted:   def
# Ground truth:  mergeDistinctPairs
# Predicted:  }
# Ground truth:  getWordSelectionRange
# Predicted:  return;
# Ground truth:  actionPerformed
# Predicted:
# Ground truth:  findVersion
# Predicted:
# Ground truth:  getUniqueId
# Predicted:  incrButton.getHeight();
# Ground truth:  getIncrementButtonHeight
# Predicted:  myNestedResult;
# Ground truth:  getNestedResult
# Predicted:  =
# Ground truth:  merge
# Predicted:  method
# Ground truth:  context
# Predicted:   public static
# Ground truth:  hyperlinkActivated
# Predicted:  myTextBg
# Ground truth:  setTextBg
# Predicted:  myMayOverflow;
# Ground truth:  mayOverflow
# Predicted:   def
# Ground truth:  addFilesTo
# Predicted:  .
# Ground truth:  toString
# Predicted:  .
# Ground truth:  enableToolsByDefault
# Predicted:
# Ground truth:  beDisabled
# Predicted:  class
# Ground truth:  inheritorOf
# Predicted:  myUserIndexer.close();
# Ground truth:  dispose
# Predicted:  return false;
# Ground truth:  isAvailableInEditorOnly
# Predicted:  return;
# Ground truth:  paintChildren
# Predicted:  ExternalSystemNode
# Ground truth:  getGroup
# Predicted:  if ( condition== null) return;
#        if (== null)
# Ground truth:  visitIfStatement
# Predicted:  this.name =
# Ground truth:  withExcludedInGutter
# Predicted:  e.getPresentation().setEnabledAndVisible(true); e.getPresentation
# Ground truth:  update
# Predicted:  myComponent.getLocationOnScreen();
# Ground truth:  getComponentLocationOnScreen
# Predicted:  .
# Ground truth:  getContentPathName
# Predicted:  return false;
# Ground truth:  generateUniqueServerName
# Predicted:  classToByPass
# Ground truth:  isInheritorDeep
# Predicted:  myLocal
# Ground truth:  dropTypeConstraint
# Predicted:   public boolean isSelected()
# Ground truth:  isGenerateDelegate
# Predicted:  .
# Ground truth:  onLineWidthsChange
# Predicted:  myCachedTokenType
# Ground truth:  clearCachedTokenType
# Predicted:  this
# Ground truth:  isPlain
# Predicted:  this
# Ground truth:  hasNextOccurence
# Predicted:  )
# Ground truth:  findIterable
# Predicted:  .
# Ground truth:  applyFix
# Predicted:  ui.setBouncing(content);
# Ground truth:  clearAttraction
# Predicted:  class
# Ground truth:  isClass
# Predicted:
# Ground truth:  refreshModelImmediately
# Predicted:  .
# Ground truth:  getGapBetweenAnnotations
# Predicted:  return false;
# Ground truth:  startInWriteAction
# Predicted:  return false;
# Ground truth:  variableValueIsUsed
# Predicted:
# Ground truth:  getPrevTokenEnd
# Predicted:  myStateIsOutOfDate;
# Ground truth:  clearDiffPresentation
# Predicted:  myTarget.hashCode(); }
# Ground truth:  hashCode
# Predicted:  model
# Ground truth:  postProcess
# Predicted:   public static String
# Ground truth:  get
# Predicted:  this.sdkName;
# Ground truth:  setSdkName
# Predicted:
# Ground truth:  shouldStop
# Predicted:  name
# Ground truth:  seemsScrambled
# Predicted:  .
# Ground truth:  parseSnippetAttribute
# Predicted:  .
# Ground truth:  getElement
# Predicted:
# Ground truth:  documentChanged
# Predicted:  myFlags
# Ground truth:  getIgnoreParentWraps
# Predicted:  return INSTANCE;
# Ground truth:  getInstance
# Predicted:  return false;
# Ground truth:  isAutoBoxed
# Predicted:  at.getFontStyle()at.getFontStyle()at.
# Ground truth:  getAttributes
# Predicted:
# Ground truth:  checkMovedAddedSourceBack
# Predicted:
# Ground truth:  addFacet
# Predicted:
# Ground truth:  isVisible
# Predicted:  myName;
# Ground truth:  getName
# Predicted:  statement
# Ground truth:  visitBlockStatement
# Predicted:  stub.isInterface();
# Ground truth:  isInterface
# Predicted:  myAreChildrenValidMappings;
# Ground truth:  areChildrenValidMappings
# Predicted:   def
# Ground truth:  isFileTypeSelected
# Predicted:  b.getBorder()
# Ground truth:  removeInsetsBeforeLayout
# Predicted:
# Ground truth:  handleScopeChooserAction
# Predicted:  return;
# Ground truth:  copyTypeParameterListIfNotReplaced
# Predicted:  e.getCaretModel().getOffset();
# Ground truth:  getVisibleOffset
# Predicted:  file.getPath();
# Ground truth:  getRelativePath
# Predicted:  return;
# Ground truth:  setProgressTask
# Predicted:
# Ground truth:  doChangeSignature
# Predicted:  true;
# Ground truth:  areConditionsNecessaryFor
# Predicted:  myProperties.size(); }
# Ground truth:  getRowCount
# Predicted:  return
# Ground truth:  size
# Predicted:  return false;
# Ground truth:  isShowFileIndentOptionsEnabled
# Predicted:  element
# Ground truth:  applyFix
# Predicted:   def
# Ground truth:  lookupStubEntriesStarted
# Predicted:
# Ground truth:  visitAntDomCustomElement
# Predicted:  type.getSort()
# Ground truth:  isStringType
# Predicted:  proportion
# Ground truth:  doSaveSplitterProportions
# Predicted:  return;
# Ground truth:  visitStatement
# Predicted:  myTitle
# Ground truth:  getCommandName
# Predicted:  myFixture.performEditorAction(IdeActions.ACTION_SELECT_ALL_O
# Ground truth:  allOccurrencesFromEditor
# Predicted:
# Ground truth:  getButtonDimension
# Predicted:  e.getScrollType()
# Ground truth:  isTouchScroll
# Predicted:  functionmyRobot.mouseMove(location.x,- diff);
#
# Ground truth:  keyPressed
# Predicted:  .
# Ground truth:  focusLost
# Predicted:  return false;
# Ground truth:  withSeparators
# Predicted:  myParent;
# Ground truth:  getParent
# Predicted:  returnnull;
#
# Ground truth:  getData
# Predicted:   def
# Ground truth:  getTextWithoutMnemonicEscaping
# Predicted:  }
# Ground truth:  buildFix
# Predicted:  instance.setSourceFilePathBytes(value);
#             instance.setSourceFilePathBytes(
# Ground truth:  setSourceFilePathBytes
# Predicted:  return;
# Ground truth:  actionPerformed
# Predicted:
# Ground truth:  updateActionText
# Predicted:  return false;
# Ground truth:  isQualified
# Predicted:  return false;
# Ground truth:  hasGenericTypeParameters
# Predicted:  myModule.getIcon();
# Ground truth:  getIcon
# Predicted:   def
# Ground truth:  getDescription
# Predicted:  return false;
# Ground truth:  isReferenceTo
# Predicted:  myIsWritable
# Ground truth:  isWritable
# Predicted:  myComponentUnderMouse.isSelected();
# Ground truth:  isSelected
# Predicted:  =
# Ground truth:  invoke
# Predicted:   def
# Ground truth:  selectTargets
# Predicted:  return
# Ground truth:  isSaveActionApplicable
# Predicted:  return;
# Ground truth:  paintComponent
# Predicted:  .
# Ground truth:  setValueAt
# Predicted:  =
# Ground truth:  update
# Predicted:  return;
# Ground truth:  visitCatchSection
# Predicted:  myState.cloneParentDir;
# Ground truth:  setCloneParentDir
# Predicted:  .
# Ground truth:  setBreadcrumbs
# Predicted:   public
# Ground truth:  clearTargetId
# Predicted:  .
# Ground truth:  createJBLabelDecorator
# Predicted:
# Ground truth:  onSearchStarted
# Predicted:  format
# Ground truth:  getMacFormat
# Predicted:  null;null;
#        value;returnnull;return
# Ground truth:  computeConstant
# Predicted:   function
# Ground truth:  createPrevOccurenceAction
# Predicted:  editor.setHighlighter(highlighter); editor.setHighlighter(highlighter);
# Ground truth:  updatePreviewHighlighter
# Predicted:  g.setColor(hoverColor);
# Ground truth:  paintTabBackground
# Predicted:  newElements
# Ground truth:  add
# Predicted:
# Ground truth:  getInstance
# Predicted:   function
# Ground truth:  add
# Predicted:  myExternalProjectsView.getTaskActivator();
# Ground truth:  getTaskActivator
# Predicted:  type
# Ground truth:  isMyQualifierType
# Predicted:  .
# Ground truth:  setParentGroupName
# Predicted:   public static
# Ground truth:  getInstance
# Predicted:  return
# Ground truth:  detectVersion
# Predicted:   function
# Ground truth:  perform
# Predicted:  //
# Ground truth:  addActionListener
# Predicted:  virtualFile.name;
# Ground truth:  copyTo
# Predicted:
# Ground truth:  simpleIfCondition
# Predicted:  .
# Ground truth:  createReplaceFieldsWithGettersPanel
# Predicted:  return
# Ground truth:  getNode
# Predicted:  this.symbols.length;
# Ground truth:  setSymbols
# Predicted:  .
# Ground truth:  isConfigurationAssigned
# Predicted:  i++;
# Ground truth:  getItemCountImpl
# Predicted:  myReplaceAll;
# Ground truth:  isReplaceAll
# Predicted:
# Ground truth:  getRangeInElement
# Predicted:  .
# Ground truth:  restorePosition
# Predicted:  myTab.getDisplayName();
# Ground truth:  getDisplayName
# Predicted:  t1;
# Ground truth:  param2
# Predicted:  return;
# Ground truth:  visitReferenceExpression
# Predicted:
# Ground truth:  setPlaceholderAttributes
# Predicted:  stack.push(to);
# Ground truth:  build
# Predicted:  myProperties.getName();
# Ground truth:  getName
# Predicted:  x.inInt(); x.inInt(); x.inInt();
# Ground truth:  method
# Predicted:  element;
# Ground truth:  isDocumentationComment
# Predicted:
# Ground truth:  getVisibleEditorRect
# Predicted:  myFile.isValid(); }
# Ground truth:  isValid
# Predicted:  compname;
# Ground truth:  getComponentName
# Predicted:  return;
# Ground truth:  scanForRootsAboveDir
# Predicted:  project
# Ground truth:  getTextFor
# Predicted:   public void doOKAction (
# Ground truth:  actionPerformed
# Predicted:
# Ground truth:  getShortcut
# Predicted:  a
# Ground truth:  method
# Predicted:  return
# Ground truth:  isEnabledByDefault
# Predicted:  myState.openRunningConfigInTab
# Ground truth:  setOpenRunningConfigInNewTab
# Predicted:  return
# Ground truth:  getWeight
# Predicted:
# Ground truth:  getEditor
# Predicted:  popup.selectUp(false);
# Ground truth:  setupUpKey
# Predicted:
# Ground truth:  equals
# Predicted:  myOptions.SOFT_WRAP_FILE_MASKS
# Ground truth:  setSoftWrapFileMasks
# Predicted:   def
# Ground truth:  isStringLiteral
# Predicted:  mySourceComponent;
# Ground truth:  getSourceComponent
# Predicted:  s
# Ground truth:  foo
# Predicted:
# Ground truth:  update
# Predicted:
# Ground truth:  setTextWithMnemonic
# Predicted:   public static
# Ground truth:  modificationCountChanged
# Predicted:  nextId;
# Ground truth:  nextId
# Predicted:  findModel
# Ground truth:  getFindModel
# Predicted:  model.remove(index); }
# Ground truth:  remove
# Predicted:   function
# Ground truth:  foo
# Predicted:  g.fill(rect);
#
#
# Ground truth:  paintComponent
# Predicted:   function
# Ground truth:  trace
# Predicted:  myState;
# Ground truth:  getLogUiState
# Predicted:   public String
# Ground truth:  displayTextInToolbar
# Predicted:  myStartingRevisionNumber;
# Ground truth:  getRevision
# Predicted:  factory
# Ground truth:  supply
# Predicted:  .
# Ground truth:  update
# Predicted:  x
# Ground truth:  run
# Predicted:  .
# Ground truth:  isUseLigatures
# Predicted:  e.
# Ground truth:  actionPerformed
# Predicted:  other
# Ground truth:  isSuperType
# Predicted:  myNodeProvider;
# Ground truth:  getNodeProvider
# Predicted:  .
# Ground truth:  onMouseClicked
# Predicted:  myOwnContent
# Ground truth:  setContents
# Predicted:  return false;
# Ground truth:  nameResolvedSuccessfully
# Predicted:   public
# Ground truth:  acceptChildren
# Predicted:   publicthis;
#
#    this;returnfalse;return
# Ground truth:  equals
# Predicted:  builder.advanceLexer();
# Ground truth:  consumeTokenFast
# Predicted:  path
# Ground truth:  getAlternativeJre
# Predicted:  return false;
# Ground truth:  isAlwaysShowPlus
# Predicted:  index
# Ground truth:  onMouseMove
# Predicted:  myInstanceOf.size()
# Ground truth:  isEnum
# Predicted:  .
# Ground truth:  setModuleOptionsMap
# Predicted:
# Ground truth:  noneSelected
# Predicted:  it.hasPrevious(); }
# Ground truth:  hasNext
# Predicted:  myField
# Ground truth:  meth
# Predicted:  .
# Ground truth:  getQualifiedName
# Predicted:  myIcon.setIcon(allIcons.Debugger.Question_badge,myIcon
# Ground truth:  setIcon
# Predicted:  myLastLeaf
# Ground truth:  charAt
# Predicted:  return
# Ground truth:  getPrevWindow
# Predicted:
# Ground truth:  performPsiSpoilingRefactoring
# Predicted:  options
# Ground truth:  showCustomOption
# Predicted:  this.trader.name =
# Ground truth:  setTrader
# Predicted:  returnfalse;
#
#        returnreturnreturnfalse;
#
#
# Ground truth:  equals
# Predicted:  this.value;
# Ground truth:  value
# Predicted:  LanguageLevel.JDK_1_8;
# Ground truth:  getDefaultLanguageLevel
# Predicted:  .
# Ground truth:  commentLeadingAsterisks
# Predicted:
# Ground truth:  appendAdditionalListItemInfo
# Predicted:  .
# Ground truth:  isStreamHoldingResource
# Predicted:  event.uri, event.source);
# Ground truth:  receive
# Predicted:  c.clone()
# Ground truth:  cloneTemplateConfiguration
# Predicted:   def
# Ground truth:  replace
# Predicted:  typeParameter
# Ground truth:  findPsiTypeForPredicate
# Predicted:   public void
# Ground truth:  run
# Predicted:  return false;
# Ground truth:  vetoesHiding
# Predicted:  returnExpression;
# Ground truth:  processReturnExpression
# Predicted:
# Ground truth:  encodeClassTypeInfoInReference
# Predicted:  .
# Ground truth:  componentResized
# Predicted:
# Ground truth:  addExtensionPointListener
# Predicted:   public
# Ground truth:  isModified
# Predicted:  addVersion(getVersion());
#
# Ground truth:  getCurrentStatus
# Predicted:  myField
# Ground truth:  meth
# Predicted:   public
# Ground truth:  actionPerformed
# Predicted:  e.getPresentation().setEnabled(visible);
#
# Ground truth:  update
# Predicted:  .
# Ground truth:  headerSize
# Predicted:  .
# Ground truth:  actionPerformed
# Predicted:  :
# Ground truth:  isValidForFile
# Predicted:  myId;
# Ground truth:  getId
# Predicted:  myFileType;
# Ground truth:  getFileType
# Predicted:  .
# Ground truth:  assertInlaysPositions
# Predicted:  method
# Ground truth:  processDeclarations
# Predicted:
# Ground truth:  saveData
# Predicted:   def
# Ground truth:  deleteTempFile
# Predicted:  myFileSet;
# Ground truth:  getFileSet
# Predicted:   public static
# Ground truth:  textChanged
# Predicted:  myParameters.getPosition();
# Ground truth:  getPosition
# Predicted:  :
# Ground truth:  setAutoScroll
# Predicted:  return
# Ground truth:  addInjectionInPlace
# Predicted:  .
# Ground truth:  fail
# Predicted:   public static
# Ground truth:  getInstance
# Predicted:  .
# Ground truth:  delete
# Predicted:  :
# Ground truth:  createEditor
# Predicted:  zzEndRead
# Ground truth:  goTo
# Predicted:  return
# Ground truth:  getStartElement
# Predicted:  myHint. cancel ()
# Ground truth:  registerHint
# Predicted:   function
# Ground truth:  setBinding
# Predicted:   def
# Ground truth:  isShiftToken
# Predicted:
# Ground truth:  compareTrimWhitespaces
# Predicted:
# Ground truth:  shortenReferences
# Predicted:  myStatus
# Ground truth:  baseExistsOrAdded
# Predicted:
# Ground truth:  invoke
# Predicted:
# Ground truth:  getTableCellRendererComponent
# Predicted:  .
# Ground truth:  getData
# Predicted:  .
# Ground truth:  getIcon
# Predicted:  scheme.isMutable(); }
# Ground truth:  canDeleteScheme
# Predicted:   def
# Ground truth:  subQualifiedName
# Predicted:  .
# Ground truth:  getTracker
# Predicted:  return
# Ground truth:  createReferences
# Predicted:  method
# Ground truth:  dispreferPreviousChainCalls
# Predicted:  include
# Ground truth:  isInclude
# Predicted:  this.name);
# Ground truth:  accept
# Predicted:
# Ground truth:  isNewServicesUIEnabled
# Predicted:  index++;
#
# Ground truth:  getRelativePathPrefix
# Predicted:  .
# Ground truth:  getInspection
# Predicted:  myClasspathFile
# Ground truth:  isClasspathFile
# Predicted:   def
# Ground truth:  endsWith
# Predicted:  owner;
# Ground truth:  isAvailable
# Predicted:  return
# Ground truth:  doMoveMethod
# Predicted:  )
# Ground truth:  isValidForFile
# Predicted:   public static DataEx
# Ground truth:  getData
# Predicted:  return
# Ground truth:  bar
# Predicted:  this.name;
# Ground truth:  getDeclaration
# Predicted:  myFoo;
# Ground truth:  getFoo
# Predicted:  myPath.getPath();
# Ground truth:  getPath
# Predicted:  component
# Ground truth:  component
# Predicted:
# Ground truth:  createRootUsage
# Predicted:  return;
# Ground truth:  updateBreakpointPresentation
# Predicted:   def
# Ground truth:  isEnabled
# Predicted:
# Ground truth:  suggestedName
# Predicted:  myIsNewLocal;
# Ground truth:  isNewLocal
# Predicted:  .
# Ground truth:  addIdentifierBytes
# Predicted:  returnfalse;
# returnfalse;
# return false;
# return
# Ground truth:  isArgumentLambdaNegated
# Predicted:  */
# Ground truth:  assertEquals
# Predicted:  value;
# Ground truth:  valueToString
# Predicted:  myCompilerOutput
# Ground truth:  getCompilerOutput
# Predicted:  inInnerClassCount++;
# Ground truth:  visitLambdaExpression
# Predicted:  f.name
# Ground truth:  meth
# Predicted:  return
# Ground truth:  containsSecondLevelNodes
# Predicted:  .
# Ground truth:  getIconForUrl
# Predicted:  onHover(table,columnOld);
#      onHover(table,
# Ground truth:  update
# Predicted:   public
# Ground truth:  actionPerformed
# Predicted:   def size()
# Ground truth:  getNumberOfSteps
# Predicted:  file
# Ground truth:  getFilePath
# Predicted:  DependencyScope.TEST;
# Ground truth:  suggestScopeByLocation
# Predicted:  project
# Ground truth:  getReferenceScope
# Predicted:  visitMaxs(maxStack, maxLocals);
# Ground truth:  visitMaxs
# Predicted:  comment
# Ground truth:  getCommentTokens
# Predicted:  return JAVA_8;
# Ground truth:  getProjectDescriptor
# Predicted:  }
# Ground truth:  putIfAbsent
# Predicted:  return false;
# Ground truth:  isAppendCall
# Predicted:  path.getLastPathComponent();
# Ground truth:  getLastNode
# Predicted:  return
# Ground truth:  isUnsaved
# Predicted:
# Ground truth:  setPermanentHeaderComponent
# Predicted:  endDrag(false);
# Ground truth:  processDragCancel
# Predicted:   public static
# Ground truth:  hideNotify
# Predicted:  compareBranches() > 0
# Ground truth:  evaluate
# Predicted:  fieldAccessibility
# Ground truth:  getFieldAccessibility
# Predicted:   public class TestMethod {
# Ground truth:  empty
# Predicted:  method
# Ground truth:  getAllowedValues
# Predicted:  myIcon.setLayerEnabled(0, myIsFavorite);
# Ground truth:  updateIcons
# Predicted:  return false;
# Ground truth:  equals
# Predicted:  breakpointManager.removeBreakpoint(breakpoint);
# Ground truth:  removeBreakpoint
# Predicted:   def
# Ground truth:  getProperty
# Predicted:  myPeer.getBackground();
# Ground truth:  getBackground
# Predicted:  return false;
# Ground truth:  equals
# Predicted:  return
# Ground truth:  getPsiFile
# Predicted:
# Ground truth:  main
# Predicted:  myTree.
# Ground truth:  getRoot
# Predicted:
# Ground truth:  enableInspections
# Predicted:
# Ground truth:  getCommunicationManager
# Predicted:  myProfileManager.name;
# Ground truth:  getProfileManager
# Predicted:  id
# Ground truth:  containsFileId
# Predicted:  myRootType;
# Ground truth:  getOrderRootType
# Predicted:
# Ground truth:  shouldFirePhysicalPsiEvents
# Predicted:  myMethod
# Ground truth:  setExcluded
# Predicted:  i2.ii<<caret>String>
# Ground truth:  foo
# Predicted:  instance.clearRelativePath();
#               instance.clearRelativePath();
#
# Ground truth:  clearRelativePath
# Predicted:  .
# Ground truth:  getSerializedSize
# Predicted:
# Ground truth:  withoutLibraries
# Predicted:  myHelpersPathLabel.setVisible(visible);
#
# Ground truth:  setTempFilesPathVisible
# Predicted:  myEditor.getCaretModel().moveToOffset(getLocalVariable().getText
# Ground truth:  moveOffsetAfter
# Predicted:  =
# Ground truth:  setParamsMessage
# Predicted:
# Ground truth:  updateAllEnabled
# Predicted:  descriptionMarkup
# Ground truth:  getDescriptionMarkup
# Predicted:  bar()
# Ground truth:  newMethod
# Predicted:  method
# Ground truth:  nextWord
# Predicted:  return RoamingType.DEFAULT;
# Ground truth:  roamingType
# Predicted:
# Ground truth:  customize
# Predicted:  event
# Ground truth:  childRemoved
# Predicted:   public void
# Ground truth:  addMethod
# Predicted:  JDK_1_5;
# Ground truth:  getLanguageLevel
# Predicted:  .
# Ground truth:  updateContextHints
# Predicted:  myIsSearchDeep;
# Ground truth:  isSearchDeep
# Predicted:  column
# Ground truth:  createBooleanCellRenderer
# Predicted:  object
# Ground truth:  getChild
# Predicted:
# Ground truth:  setSecondaryActionsIcon
# Predicted:  myValue;
# Ground truth:  getValue
# Predicted:  lineNumber
# Ground truth:  convert
# Predicted:
# Ground truth:  isLanguageExtension
# Predicted:   function bulkUpdateFinished ( )
# Ground truth:  notifyListenersOnBulkModeFinished
# Predicted:  myRole
# Ground truth:  hasExtension
# Predicted:  x
# Ground truth:  getEntryPointRect
# Predicted:  this.framework = framework;
# Ground truth:  setFramework
# Predicted:   function
# Ground truth:  main
# Predicted:  return false;
# Ground truth:  isDataExcluded
# Predicted:  font
# Ground truth:  getFont
# Predicted:  codeStyleObjectDescriptor
# Ground truth:  collectCommonLanguageProperties
# Predicted:  .
# Ground truth:  createAdditionalItems
# Predicted:  object
# Ground truth:  equals
# Predicted:  )
# Ground truth:  resetEditorFrom
# Predicted:  return
# Ground truth:  shouldSearchInLanguage
# Predicted:  .
# Ground truth:  toString
# Predicted:  virtualFile
# Ground truth:  synchronizeTempDirVfs
# Predicted:  value
# Ground truth:  doCopyToClipboardAction
# Predicted:
# Ground truth:  closeEditor
# Predicted:  pattern
# Ground truth:  buildPatternMatcher
# Predicted:  CHECK_BOX;
# Ground truth:  getAccessibleRole
# Predicted:  width
# Ground truth:  getMainPanelPreferredSize
# Predicted:  myLength.getLength();
# Ground truth:  getLength
# Predicted:  method
# Ground truth:  traceWasStarted
# Predicted:  module
# Ground truth:  getInstance
# Predicted:  m_numLocksHeld--;
# Ground truth:  elementFinished
# Predicted:
# Ground truth:  visitMethodCallExpression
# Predicted:  return false;
# Ground truth:  supportsStubs
# Predicted:
# Ground truth:  getAlternativeText
# Predicted:  return;
# Ground truth:  visitPolyadicExpression
# Predicted:   def
# Ground truth:  getAttributes
# Predicted:  return
# Ground truth:  getToArrayDescriptor
# Predicted:  return false;
# Ground truth:  tryStatementMayCompleteNormally
# Predicted:  method
# Ground truth:  setTarget
# Predicted:  builder
# Ground truth:  createOperation
# Predicted:  return
# Ground truth:  createViewer
# Predicted:  class
# Ground truth:  visitClass
# Predicted:   def
# Ground truth:  createProcessHandler
# Predicted:  myComponent);
#
# Ground truth:  getPresentation
# Predicted:  this
# Ground truth:  equals
# Predicted:  proxy
# Ground truth:  isRoot
# Predicted:  visitor
# Ground truth:  getUnreachableStatement
# Predicted:  .
# Ground truth:  setIcons
# Predicted:  listValue:
# Ground truth:  example
# Predicted:  g.setClip(x2, y2);
#        g.setClip
# Ground truth:  clip
# Predicted:
# Ground truth:  updateIcon
# Predicted:  group.addGroup(subGroup); }
# Ground truth:  fillGroupIgnorePopupFlag
# Predicted:
# Ground truth:  wait
# Predicted:  }
# Ground truth:  createCompositeNode
# Predicted:  myJavaSession.getContextManager();
# Ground truth:  getDebuggerStateManager
# Predicted:  component.projectOpened();
# Ground truth:  projectOpened
# Predicted:  return;
# Ground truth:  pass
# Predicted:  axis
# Ground truth:  getMinimumSpan
# Predicted:  type
# Ground truth:  isCompatibleWithOriginalRunConfiguration
# Predicted:  myNonBlockingLoad
# Ground truth:  isNonBlockingLoad
# Predicted:  .
# Ground truth:  getContainingFile
# Predicted:  myOption.getId()
# Ground truth:  getValue
# Predicted:  pt
# Ground truth:  viewToModel
# Predicted:  e.val;
# Ground truth:  get
# Predicted:  DumbProgressIndicator.INSTANCE;
# Ground truth:  getProgressIndicator
# Predicted:  )
# Ground truth:  update
# Predicted:  xxxx;
# Ground truth:  getXxxx
# Predicted:  return toString(); }
# Ground truth:  getPresentableName
# Predicted:  function
# Ground truth:  isResourceVariable
# Predicted:   def method_name ( )
# Ground truth:  main
# Predicted:   def
# Ground truth:  compare
# Predicted:  .
# Ground truth:  buildVisitor
# Predicted:  method
# Ground truth:  isMovableMember
# Predicted:  setBackground(ourBackground);setOpaque(false);setOpaque(
# Ground truth:  init
# Predicted:  .
# Ground truth:  getPolyadicKind
# Predicted:  :
# Ground truth:  mouseMoved
# Predicted:  component
# Ground truth:  setTargetComponent
# Predicted:  return
# Ground truth:  canRepresent
# Predicted:  .
# Ground truth:  actionPerformed
# Predicted:  myVirtualMachine.mirrorOf(s); }
# Ground truth:  mirrorOf
# Predicted:  file.getCharset()
# Ground truth:  isBOMMandatory
# Predicted:   public String
# Ground truth:  Runnable
# Predicted:   public static
# Ground truth:  shouldIgnore
# Predicted:
# Ground truth:  getMinimumSize
# Predicted:  .
# Ground truth:  isSelected
# Predicted:  myRecorderId
# Ground truth:  getFilesToSendProvider
# Predicted:  contentManager.setSelectedContent(content);
# Ground truth:  selectContentByContributor
# Predicted:   public String
# Ground truth:  accept
# Predicted:  .
# Ground truth:  toString
# Predicted:  null
# Ground truth:  restoreBySignature
# Predicted:  return
# Ground truth:  zzCanGrow
# Predicted:  method
# Ground truth:  run
# Predicted:  myState.isShowWithDiffOnly
# Ground truth:  setShowDiffOnly
# Predicted:  return
# Ground truth:  getTotalLength
# Predicted:  .
# Ground truth:  isInlineThis
# Predicted:  item
# Ground truth:  getPresentation
# Predicted:  method
# Ground truth:  run
# Predicted:  .
# Ground truth:  isSyncScrollEnabled
# Predicted:   public)
# Ground truth:  updateNotifications
# Predicted:   def
# Ground truth:  update
# Predicted:  if!(containingClass instanceof PsiMethod)!(containingClass
# Ground truth:  canHaveSiblingSuper
# Predicted:  return
# Ground truth:  isVisibilitySupported
# Predicted:
# Ground truth:  apply
# Predicted:
# Ground truth:  matches
# Predicted:  myChanges.size()
# Ground truth:  getLastChange
# Predicted:  return
# Ground truth:  buildQuickFixesOnlyForOnTheFlyErrors
# Predicted:  myNode;
# Ground truth:  createFavoriteListNode
# Predicted:  myHighlighterShowRequest.run();
# Ground truth:  onTimer
# Predicted:  b<caret>
# Ground truth:  main
# Predicted:  myName;
# Ground truth:  getName
# Predicted:  bitField0_
# Ground truth:  hasMostSigBits
# Predicted:  myRemoteSdkProperties.isRunAsRootViaSudo(); }
# Ground truth:  isRunAsRootViaSudo
# Predicted:  e1.isEquivalentTo(e2); }
# Ground truth:  areEquivalent
# Predicted:  host;
# Ground truth:  getHost
# Predicted:  System.out.println(1);
# Ground truth:  newMethod
# Predicted:  myPopup.isVisible();
# Ground truth:  isVisible
# Predicted:  currSettings.copyFrom(scheme);
#
# Ground truth:  restoreDefaults
# Predicted:  return false;
# Ground truth:  isSuitablePrimitiveType
# Predicted:  .
# Ground truth:  stateChanged
# Predicted:  .
# Ground truth:  setTransparencyChessboardVisible
# Predicted:  pathElement.setAttribute(METHOD,
# Ground truth:  writeExternal
# Predicted:  return
# Ground truth:  getNewContentRevision
# Predicted:  .
# Ground truth:  onEnvironmentPrepared
# Predicted:   def
# Ground truth:  DirectoryInfo
# Predicted:  event.getPresentation().setEnabled(!window.getAnchor().isHorizontal());
# Ground truth:  update
# Predicted:  t
# Ground truth:  removeExplicitExtension
# Predicted:  onValidThread(this::promiseRootEntry);
# Ground truth:  getRoot
# Predicted:  pair.scope;
# Ground truth:  valueOf
# Predicted:  inputString
# Ground truth:  canClose
# Predicted:  return
# Ground truth:  substituteElementToRename
# Predicted:   def
# Ground truth:  getEditingPath
# Predicted:
# Ground truth:  associate
# Predicted:
# Ground truth:  attributesEqual
# Predicted:  factory
# Ground truth:  isMapType
# Predicted:  method
# Ground truth:  setupDebugger
# Predicted:   def
# Ground truth:  getState
# Predicted:  .
# Ground truth:  storeCharset
# Predicted:
# Ground truth:  addFrameworkListener
# Predicted:  )
# Ground truth:  onClosed
# Predicted:   def
# Ground truth:  getBundleQName
# Predicted:  //
# Ground truth:  actionPerformed
# Predicted:  field
# Ground truth:  buildFix
# Predicted:  myPopup.skipCaretEvent = true;
# Ground truth:  appendSearchText
# Predicted:   public String
# Ground truth:  getMigrationPackage
# Predicted:  size
# Ground truth:  getSize
# Predicted:  return;
# Ground truth:  visitClass
# Predicted:  .
# Ground truth:  compareTo
# Predicted:   function
# Ground truth:  prepareAnimations
# Predicted:  method
# Ground truth:  buildVisitor
# Predicted:  call
# Ground truth:  tryExtract
# Predicted:  return isEmpty(); }
# Ground truth:  isEmptyTextVisible
# Predicted:  myGuardsSuppressed
# Ground truth:  suppressGuardedExceptions
# Predicted:  fieldType
# Ground truth:  isCallableOrRunnable
# Predicted:  inspectionSessions.incrementAndGet();
# Ground truth:  reportInspectionsWhichReportedProblems
# Predicted:  a method
# Ground truth:  foo
# Predicted:  myMessage;
# Ground truth:  toString
# Predicted:  bitField0_
# Ground truth:  hasGlobalOptionsPath
# Predicted:   def
# Ground truth:  fromExternal
# Predicted:  myMouseIsOverThumb
# Ground truth:  mouseExited
# Predicted:  myChanged.add(path);
# Ground truth:  invalidate
# Predicted:  =
# Ground truth:  getPositionInfo
# Predicted:  .
# Ground truth:  ensureUpToDate
# Predicted:  enabled
# Ground truth:  isModified
# Predicted:  hash
# Ground truth:  getHashCode
# Predicted:  caret>
# Ground truth:  method
# Predicted:  Foo::m
# Ground truth:  main
# Predicted:  o.name;
# Ground truth:  getSubSequenceWithHashCode
# Predicted:  b1;
# Ground truth:  newMethod
# Predicted:
# Ground truth:  getEvaluationMode
# Predicted:  .
# Ground truth:  hashCode
# Predicted:  value
# Ground truth:  getIcon
# Predicted:  ui.setBouncing(content);
# Ground truth:  clearAttraction
# Predicted:  field.name
# Ground truth:  isPublic
# Predicted:   public void run()
# Ground truth:  invokeLaterIfNeeded
# Predicted:
# Ground truth:  setOutputObject
# Predicted:  return;
# Ground truth:  showNotify
# Predicted:  state.SHOW_DETAILS_PANEL = value;
# Ground truth:  setShowDetailsInPushDialog
# Predicted:  .
# Ground truth:  cancel
# Predicted:   public static String
# Ground truth:  buildFix
# Predicted:  g.fill(myArea);
# Ground truth:  executePaint
# Predicted:  .
# Ground truth:  update
# Predicted:  return asMap().size(); }
# Ground truth:  size
# Predicted:  access
# Ground truth:  isGenerated
# Predicted:  separator
# Ground truth:  getListCellRendererComponent
# Predicted:  .
# Ground truth:  toString
# Predicted:  access
# Ground truth:  isTransitive
# Predicted:   public)return;
#      return;
# return;
#
# Ground truth:  applyFix
# Predicted:
# Ground truth:  getCompleteCommand
# Predicted:  srcDirectories[0]
# Ground truth:  performAction
# Predicted:  ourInstance;
# Ground truth:  getInstance
# Predicted:  return false;
# Ground truth:  canUnwrapBlock
# Predicted:   def
# Ground truth:  calcIgnored
# Predicted:   public static String
# Ground truth:  getPreferredFocusableComponent
# Predicted:  myMethod
# Ground truth:  setOriginInfo
# Predicted:  return false;
# Ground truth:  isCollapseMethodByDefault
# Predicted:  value
# Ground truth:  main
# Predicted:
# Ground truth:  m
# Predicted:  file.getUserData(VFS_URL_KEY); }
# Ground truth:  getOriginalFileUrl
# Predicted:  .
# Ground truth:  endProgress
# Predicted:
# Ground truth:  readExternal
# Predicted:  path.getPathCount();
# Ground truth:  contains
# Predicted:   function
# Ground truth:  remove
# Predicted:
# Ground truth:  canMergeWith
# Predicted:  return
# Ground truth:  getContentAt
# Predicted:  myExcludedRoots.add(pointer);
# Ground truth:  removeExcludedRoot
# Predicted:  return false;
# Ground truth:  needExpandAll
# Predicted:  moduleDataNode.getData());
# Ground truth:  removeData
# Predicted:  return;
# Ground truth:  checkChanges
# Predicted:  myOriginalVar
# Ground truth:  createName
# Predicted:  ctx.getScale(OBJ_SCALE.of(zoom));
#
# Ground truth:  apply
# Predicted:  category:
# Ground truth:  getInstance
# Predicted:  .
# Ground truth:  update
# Predicted:  instance.setFieldName(value);
#             instance.setFieldName(value);
#
# Ground truth:  setFieldName
# Predicted:  myDelegatedTarget;
# Ground truth:  getDelegatedTarget
# Predicted:  myOriginalManifestFiles.clear();
#     myOriginalOriginalManifestFiles.clear();
#
# Ground truth:  clear
# Predicted:  myLocalFS.getSeparator();
# Ground truth:  getSeparator
# Predicted:  superChange.markChildChanged(eachParent, 0);
# Ground truth:  integrateIntoExistingChanges
# Predicted:  .
# Ground truth:  h
# Predicted:   public void startWatching (
# Ground truth:  resumeAction
# Predicted:   public void doOKAction (
# Ground truth:  handleDoubleClickOrEnter
# Predicted:
# Ground truth:  contentChanged
# Predicted:   public static String
# Ground truth:  loadDefaultLiveTemplates
# Predicted:
# Ground truth:  commitModel
# Predicted:  parent.setLocation(child);
#
# Ground truth:  setRelativeBounds
# Predicted:  myDirtyDirs.add(newcomer);
#
# Ground truth:  addDirtyDirRecursively
# Predicted:  myInputEvent
# Ground truth:  setInputEvent
# Predicted:  return
# Ground truth:  foo3
# Predicted:  type.name;
# Ground truth:  nearestAccessibleType
# Predicted:  .
# Ground truth:  setCompactDirectories
# Predicted:  myCustomNode;
# Ground truth:  isCustomNode
# Predicted:  .
# Ground truth:  getResolveScope
# Predicted:
# Ground truth:  dataPackArrived
# Predicted:  :
# Ground truth:  mouseClicked
# Predicted:  : psiElements.add(pair.first);
# Ground truth:  applyFix
# Predicted:  size
# Ground truth:  showValuePopup
# Predicted:  path
# Ground truth:  hasEntry
# Predicted:  myAlarm.cancelAllRequests();
#
# Ground truth:  setupListeners
# Predicted:  myCanBeAbsent
# Ground truth:  createOrGet
# Predicted:  .
# Ground truth:  getSerializedSize
# Predicted:  .
# Ground truth:  writeExternal
# Predicted:  var
# Ground truth:  resolveOrderFast
# Predicted:  myDirectory.getVirtualFile(); }
# Ground truth:  getVirtualFile
# Predicted:   public static
# Ground truth:  createItemComponent
# Predicted:  .
# Ground truth:  printOn
# Predicted:  codeStyleData.name);
# Ground truth:  valueChanged
# Predicted:  mySubstitutor);
# Ground truth:  getSubstitutor
# Predicted:  function
# Ground truth:  charAt
# Predicted:  qualifierExpression
# Ground truth:  isStaticallyReferenced
# Predicted:  return false;
# Ground truth:  isArrayLookup
# Predicted:  return
# Ground truth:  withField
# Predicted:  return false;
# Ground truth:  isUseFileNestingRules
# Predicted:  myDebugName;
# Ground truth:  toString
# Predicted:  parent.name;
# Ground truth:  getParent
# Predicted:  .
# Ground truth:  getPushDownHandler
# Predicted:  .
# Ground truth:  registerFixesForExpressionStatement
# Predicted:  myValueDescriptor.getProject();
# Ground truth:  getProject
# Predicted:  breakpoint
# Ground truth:  getBreakpointPresentation
# Predicted:  family.family.name
# Ground truth:  setFamily
# Predicted:  return false;
# Ground truth:  attributeListsEqual
# Predicted:   public static
# Ground truth:  getInspection
# Predicted:  .
# Ground truth:  getDetectorById
# Predicted:  .
# Ground truth:  getInstance
# Predicted:  myAltPressed
# Ground truth:  resetState
# Predicted:  problems
# Ground truth:  run
# Predicted:  return;
# Ground truth:  startMonitor
# Predicted:  editor
# Ground truth:  invoke
# Predicted:  !BasicJavaAstTreeUtil.is(node, BASIC_JAVA_COMMENT_
# Ground truth:  canSelect
# Predicted:  functionfunctionfunction
# Ground truth:  isExpressionStatementExpression
# Predicted:   public static
# Ground truth:  hideBalloon
# Predicted:
# Ground truth:  getHtmlWithFonts
# Predicted:
# Ground truth:  main
# Predicted:  .
# Ground truth:  getLogicalBounds
# Predicted:  show;myOptions.SHOW_INSPECTION_WIDGET
# Ground truth:  setShowInspectionWidget
# Predicted:  this.name;
# Ground truth:  s
# Predicted:  myTree.revalidate();
# Ground truth:  updateContainer
# Predicted:
# Ground truth:  computeCastTo
# Predicted:  mySandboxHome
# Ground truth:  getSandboxHome
# Predicted:  return JAVA_11;
# Ground truth:  getProjectDescriptor
# Predicted:   def
# Ground truth:  visitLambdaExpression
# Predicted:  thread.getId()
# Ground truth:  getCurrentIndicator
# Predicted:  return
# Ground truth:  buildFix
# Predicted:  .
# Ground truth:  main
# Predicted:  return
# Ground truth:  tryConsumeIteration
# Predicted:  function
# Ground truth:  canBeCreatedInQualifiedNew
# Predicted:  .
# Ground truth:  getCanonicalText
# Predicted:  }
# Ground truth:  maybeShowFor
# Predicted:  .
# Ground truth:  isPaintSelection
# Predicted:  return;
# Ground truth:  addProblemElement
# Predicted:  myIsEAP;
# Ground truth:  isEAP
# Predicted:  return;
# Ground truth:  invoke
# Predicted:  onFileChange(event)
# Ground truth:  fileCreated
# Predicted:  .........
# Ground truth:  checkFontSize
# Predicted:   public static
# Ground truth:  pauseExecution
# Predicted:  return
# Ground truth:  load
# Predicted:  (context, children.get(0))
# Ground truth:  deserialize
# Predicted:  addDesc(desc);
# Ground truth:  visitAnnotation
# Predicted:  ourWhitespaceCharacter;
# Ground truth:  whitespaceCharacter
# Predicted:   def
# Ground truth:  isSearchMatch
# Predicted:  myClassReference;
# Ground truth:  getClassReference
# Predicted:
# Ground truth:  setSelectedChar
# Predicted:  myRoot;
# Ground truth:  getComponent
# Predicted:  myDebugSessionListener.setActive(true);
#
# Ground truth:  doPause
# Predicted:  above
# Ground truth:  getInlaysHeight
# Predicted:  x.close();
# Ground truth:  example
# Predicted:  string
# Ground truth:  matchingDegree
# Predicted:
# Ground truth:  isVarArgs
# Predicted:  return
# Ground truth:  toNode
# Predicted:  myComponent
# Ground truth:  restoreInGrid
# Predicted:
# Ground truth:  applyFix
# Predicted:  :
# Ground truth:  update
# Predicted:  .
# Ground truth:  showStandaloneDiff
# Predicted:  pattern
# Ground truth:  isSelectedByTyping
# Predicted:  return;
# Ground truth:  chooseFileAndExport
# Predicted:  visitAntDomElement(property);
# Ground truth:  visitProperty
# Predicted:  }
# Ground truth:  createPage
# Predicted:  function
# Ground truth:  findJarByClass
# Predicted:  i
# Ground truth:  explicitDirection
# Predicted:  myLocalVirtualFile
# Ground truth:  cancelDownloading
# Predicted:  function
# Ground truth:  isCollapsedByDefault
# Predicted:  FLUSHED_ALL;
#
# Ground truth:  and
# Predicted:  project.getService(PropertiesComponent.class);
# Ground truth:  getInstance
# Predicted:  isRefreshable_ ;
# Ground truth:  getIsRefreshable
# Predicted:  return;
# Ground truth:  replaceMergeableImplicitIf
# Predicted:  return
# Ground truth:  convertModuleName
# Predicted:  myComponent;
# Ground truth:  getComponent
# Predicted:  .
# Ground truth:  setToBeShown
# Predicted:  )
# Ground truth:  invokeLater
# Predicted:
# Ground truth:  isCutEnabled
# Predicted:  local();
#
# Ground truth:  extracted
# Predicted:  myHint
# Ground truth:  getHint
# Predicted:   public
# Ground truth:  isCountFilterEnabled
# Predicted:  myContext. close();
# Ground truth:  close
# Predicted:  .
# Ground truth:  supportsOverloadSwitching
# Predicted:   public static
# Ground truth:  create
# Predicted:  .
# Ground truth:  focusLost
# Predicted:  null
# Ground truth:  checkResidence
# Predicted:
# Ground truth:  notifySuccess
# Predicted:  .
# Ground truth:  profilesInitialized
# Predicted:   public void install (
# Ground truth:  visitEnd
# Predicted:  .
# Ground truth:  setSelected
# Predicted:  //
# Ground truth:  registerJavacFileData
# Predicted:  this.name;
# Ground truth:  getState
# Predicted:  .
# Ground truth:  processContextHints
# Predicted:  text
# Ground truth:  replace
# Predicted:   public static
# Ground truth:  createCenterPanel
# Predicted:   public PsiMethodCallExpression
# Ground truth:  getDirectParentMethod
# Predicted:  =
# Ground truth:  buildFix
# Predicted:  SHORT_MASK
# Ground truth:  getUnixMode
# Predicted:  return
# Ground truth:  getProjectCompileScope
# Predicted:  text
# Ground truth:  markWhitespaceForReformat
# Predicted:   public String
# Ground truth:  requestFocusWithFallback
# Predicted:  index
# Ground truth:  addTargets
# Predicted:   function MakeStaticHandler ( )
# Ground truth:  getHandler
# Predicted:  i
# Ground truth:  findFirst
# Predicted:  return
# Ground truth:  getTableCellEditorComponent
# Predicted:  return
# Ground truth:  getRBrace
# Predicted:  .
# Ground truth:  actionPerformed
# Predicted:  .
# Ground truth:  main
# Predicted:   def
# Ground truth:  validateEntryPoints
# Predicted:  myShowingListModel.setSearchFurtherBtnsEnabled(
#           false
# Ground truth:  updateInEdt
# Predicted:  mySession.shouldBeRefreshed(); }
# Ground truth:  shouldBeRefreshed
# Predicted:  i = indexes.index(method)
# Ground truth:  getOriginal
# Predicted:  return
# Ground truth:  findTagName
# Predicted:   function
# Ground truth:  removeElementsMarkListener
# Predicted:  caret
# Ground truth:  run
# Predicted:  target
# Ground truth:  isTargetOutputCleared
# Predicted:  myContextModule;
# Ground truth:  getModule
# Predicted:  return key; }
# Ground truth:  removeFrom
# Predicted:  block)block.getStart());
#    block.getEnd();
#
# Ground truth:  createDiffContent
# Predicted:  return contentType;
# Ground truth:  toString
# Predicted:  myArtifactsStructureConfigurable;
# Ground truth:  getArtifactsStructureConfigurable
# Predicted:  field.getText()
# Ground truth:  isModified
# Predicted:  myPreferedFocusComponent
# Ground truth:  dispose
# Predicted:  return
# Ground truth:  createLookupElement
# Predicted:   public void
# Ground truth:  run
# Predicted:  ;
# Ground truth:  run
# Predicted:  myMover.move(myDirection);
# Ground truth:  actionPerformed
# Predicted:  =
# Ground truth:  isStaleIdDeletion
# Predicted:
# Ground truth:  isFlattenPackages
# Predicted:   def
# Ground truth:  reduceClasses
# Predicted:  .
# Ground truth:  getUnimportantLineCharCount
# Predicted:  bitField0_
# Ground truth:  hasProblemLocationOffset
# Predicted:  seq. size ()
# Ground truth:  sizeOf
# Predicted:   public String
# Ground truth:  createDeploymentConfiguration
# Predicted:  return false;
# Ground truth:  startInWriteAction
# Predicted:  vcsName
# Ground truth:  getVcsName
# Predicted:
# Ground truth:  notifyPropertyExpanded
# Predicted:  method
# Ground truth:  addParameters
# Predicted:
# Ground truth:  perform
# Predicted:  type
# Ground truth:  serialize
# Predicted:
# Ground truth:  before
# Predicted:  .
# Ground truth:  remove
# Predicted:  component.setBorder(IdeBorderFactory.createTitledBorder(rootComponent
# Ground truth:  createComponent
# Predicted:  myHomeComponent.getText() ;
# Ground truth:  getHomeValue
# Predicted:   public static
# Ground truth:  documentChanged
# Predicted:  StringBufferReplaceableByStringFix(typeText);
#
# Ground truth:  buildFix
# Predicted:  bufferPosition
# Ground truth:  getBufferPosition
# Predicted:  return;
# Ground truth:  invokeLater
# Predicted:  name
# Ground truth:  getDisplayName
# Predicted:  System.out.println(x);
#
# Ground truth:  newMethod
# Predicted:  .
# Ground truth:  setSelectedIndex
# Predicted:  return;
# Ground truth:  visitLocalVariable
# Predicted:  return false;
# Ground truth:  toolWindowIsNotEmpty
# Predicted:  this.name;
#        this.age;
#        this.age;
# Ground truth:  isStandardEqualsMethod
# Predicted:  myValue
# Ground truth:  hashCode
# Predicted:  return
# Ground truth:  compareTo
# Predicted:  return
# Ground truth:  getChildText
# Predicted:   public
# Ground truth:  processPresentation
# Predicted:  myMapper.getText()
# Ground truth:  getMerger
# Predicted:
# Ground truth:  getRenderer
# Predicted:  .
# Ground truth:  editExternalAnnotation
# Predicted:
# Ground truth:  stopEditing
# Predicted:  return;
# Ground truth:  paintSelectionOnFirstSoftWrapLineIfNecessary
# Predicted:   def
# Ground truth:  actionPerformed
# Predicted:  function
# Ground truth:  resolveClassCreatedByFunction
# Predicted:
# Ground truth:  fileCopied
# Predicted:  = null;
# 		myField == null;
# 		myField
# Ground truth:  meth
# Predicted:  function
# Ground truth:  findLeftmostLParen
# Predicted:
# Ground truth:  getControlOffset
# Predicted:   public static String
# Ground truth:  actionPerformed
# Predicted:  return
# Ground truth:  setLength
# Predicted:  return iter.next(); }
# Ground truth:  next
# Predicted:  return
# Ground truth:  visitQualifiedReferenceExpression
# Predicted:   public static
# Ground truth:  disable
# Predicted:  sub
# Ground truth:  getLongIndex
# Predicted:
# Ground truth:  clearVariants
# Predicted:   public void
# Ground truth:  addListener
# Predicted:  owner
# Ground truth:  isNotNull
# Predicted:  anchorElement
# Ground truth:  applyFix
# Predicted:  key
# Ground truth:  isIgnored
# Predicted:  return
# Ground truth:  getTreeView
# Predicted:  this.name;
# Ground truth:  archive
# Predicted:  myRepository
# Ground truth:  getRepository
# Predicted:  return;
# Ground truth:  visitMethod
# Predicted:
# Ground truth:  drawString
# Predicted:  library
# Ground truth:  addSupport
# Predicted:   function
# Ground truth:  visitRegExpNumber
# Predicted:  myCurrentToken.updateData(myPosition);
# Ground truth:  handleTokenNotFound
# Predicted:   public
# Ground truth:  copy
# Predicted:  .
# Ground truth:  getNavigationElement
# Predicted:  .
# Ground truth:  setVisible
# Predicted:
# Ground truth:  writeExternal
# Predicted:  return false;
# Ground truth:  isTargetedToProduct
# Predicted:  linelinelinelinelinelinelinelineline);
# Ground truth:  getVisibleInterval
# Predicted:  this method
# Ground truth:  getOwner
# Predicted:
# Ground truth:  isEnabled
# Predicted:  myArgFile;
# Ground truth:  isArgFile
# Predicted:  path
# Ground truth:  getContentRoot
# Predicted:  return;
# Ground truth:  visitMethodCallExpression
# Predicted:  test.x(new <caret>);
# Ground truth:  main
# Predicted:
# Ground truth:  runOnFrame
# Predicted:  text.append(leafText);
# Ground truth:  visitElement
# Predicted:  lineLength
# Ground truth:  isBelowRightMargin
# Predicted:   public void clear (
# Ground truth:  clear
# Predicted:  )
# Ground truth:  update
# Predicted:   def
# Ground truth:  containsKey
# Predicted:  myIsEnabled
# Ground truth:  setEnabled
# Predicted:  return
# Ground truth:  isCopyEnabled
# Predicted:  method
# Ground truth:  register
# Predicted:  return false;
# Ground truth:  processTextOccurrence
# Predicted:  GROUP
# Ground truth:  getGroup
# Predicted:
# Ground truth:  reportToFUS
# Predicted:  ;}
# Ground truth:  isVarargAsArray
# Predicted:  name
# Ground truth:  getString
# Predicted:  parent.getFocusTraversalPolicy();
# Ground truth:  getPreferredFocusedComponent
# Predicted:   function
# Ground truth:  visitArrayAccessExpression
# Predicted:   function
# Ground truth:  renderNumericValue
# Predicted:  class
# Ground truth:  getClassOrPackageListener
# Predicted:  .);}
# Ground truth:  layout
# Predicted:  path = myMap.get(path);
# Ground truth:  contains
# Predicted:  aClass.visitClass(aClass);
# Ground truth:  visitClass
# Predicted:  watcher.start();
# Ground truth:  register
# Predicted:   function
# Ground truth:  fireFocusLost
# Predicted:  myScopeMatch;
# Ground truth:  setScopeMatch
# Predicted:  myEntries.get(0).hashCode();
# Ground truth:  hashCode
# Predicted:  foldingModel.setFoldingEnabled(true);
# Ground truth:  doInit
# Predicted:  showBelow(component, group);
# Ground truth:  showBelow
# Predicted:  String
# Ground truth:  ddd
# Predicted:  :
# Ground truth:  assertCompatibleSerialization
# Predicted:  .
# Ground truth:  startNotified
# Predicted:  )end.line);end.line);
# Ground truth:  getPreferredWidthOfVisibleLines
# Predicted:  myPrevPresentation;
# Ground truth:  getPrevPresentation
# Predicted:  expression
# Ground truth:  hasReferences
# Predicted:  Set;
# Ground truth:  meth
# Predicted:  value
# Ground truth:  setSearchInComments
# Predicted:  .
# Ground truth:  isProvidedScopeIncluded
# Predicted:  staticField.staticField = staticField;
# Ground truth:  inReturnType
# Predicted:  myList.add(type);
#       mySet.add(type);
#
# Ground truth:  visitClass
# Predicted:  return false;
# Ground truth:  supportsManualOrder
# Predicted:  myPathTextField.getField().getRootPane()!= null;
# Ground truth:  isTextFieldActive
# Predicted:  return
# Ground truth:  isDumbAware
# Predicted:  fixed;
# Ground truth:  isFixed
# Predicted:
# Ground truth:  positionCaret
# Predicted:  returnreturn
# Ground truth:  weigh
# Predicted:  myConsiderCaretPositionOnDocumentUpdates;
# Ground truth:  setConsiderCaretPositionOnDocumentUpdates
# Predicted:
# Ground truth:  isToBeShown
# Predicted:  .
# Ground truth:  main
# Predicted:   public static String
# Ground truth:  focusGained
# Predicted:  )
# Ground truth:  createChooseByNamePopupComponent
# Predicted:  )
# Ground truth:  processChangesByVcs
# Predicted:   public static String
# Ground truth:  getInspection
# Predicted:
# Ground truth:  setText
# Predicted:  myName
# Ground truth:  setName
# Predicted:  .
# Ground truth:  toBackground
# Predicted:  component
# Ground truth:  setMethod
# Predicted:  == null== null== null== null== null== null
# Ground truth:  equals
# Predicted:  return
# Ground truth:  isDumbAware
# Predicted:  this.i;
# Ground truth:  setI
# Predicted:  :
# Ground truth:  fireGlobalScrollBarValueChangedFromOutside
# Predicted:  myText
# Ground truth:  setText
# Predicted:  method
# Ground truth:  base
# Predicted:  myHasNext
# Ground truth:  reset
# Predicted:
# Ground truth:  main
# Predicted:  return
# Ground truth:  executeImpl
# Predicted:  valueToBeSet
# Ground truth:  actionPerformed
# Predicted:  variable
# Ground truth:  findNextAssignment
# Predicted:   function
# Ground truth:  processReferences
# Predicted:  editor.reset();
# Ground truth:  resetEditors
# Predicted:  val;
# Ground truth:  getValue
# Predicted:  iconWidth
# Ground truth:  LayeredIcon
# Predicted:
# Ground truth:  staticMethod
# Predicted:   function
# Ground truth:  addContextListener
# Predicted:  action
# Ground truth:  wrapAsTextButton
# Predicted:  mySdk
# Ground truth:  getSdk
# Predicted:  ;
# Ground truth:  getClassesCount
# Predicted:  return false;
# Ground truth:  isHidden
# Predicted:  annotation
# Ground truth:  findGuardForMember
# Predicted:  )
# Ground truth:  setupComponents
# Predicted:  PsiElementPsiElementPsiElementPsiTreeUtil.skip
# Ground truth:  isSingleNameValuePair
# Predicted:
# Ground truth:  addOption
# Predicted:  element
# Ground truth:  isReferenceTo
# Predicted:  return false;
# Ground truth:  isCommunity
# Predicted:
# Ground truth:  addAdditionalTabComponent
# Predicted:  .
# Ground truth:  makeWritable
# Predicted:   def
# Ground truth:  deriveIsAnonymous
# Predicted:   def
# Ground truth:  hasFsEvent
# Predicted:  value;
# Ground truth:  getValue
# Predicted:  this.value;
# Ground truth:  toString
# Predicted:  key:
# Ground truth:  main
# Predicted:  return false;
# Ground truth:  isInQualifiedNew
# Predicted:  return
# Ground truth:  isKeyboard
# Predicted:  myFavoritesRootsOrder.add(index);
#
# ...
# Ground truth:  acceptFile
# Predicted:  .
# Ground truth:  positionReachedInternal
# Predicted:   def
# Ground truth:  hashCode
# Predicted:  action.name;
# Ground truth:  getOrCreateAction
# Predicted:  )
# Ground truth:  performCommand
# Predicted:  method
# Ground truth:  shouldProcess
# Predicted:  myOnEdt;
# Ground truth:  runInDispatchThread
# Predicted:   public MethodBuilder append(String str)
# Ground truth:  append
# Predicted:  modCount;
# Ground truth:  packValues
# Predicted:  b.delegatedBaseMethod(); }
# Ground truth:  parameterUsageMethod
# Predicted:  l
# Ground truth:  getStrings
# Predicted:
# Ground truth:  visitAnnotationParameter
# Predicted:  context
# Ground truth:  registerFilterToSkipMarkingAffectedFileDirty
# Predicted:  onDemandImportInspection();
# Ground truth:  getInspection
# Predicted:  ref.name()
# Ground truth:  getTrackingType
# Predicted:  return false;
# Ground truth:  isNullObject
# Predicted:
# Ground truth:  getDelay
# Predicted:  return
# Ground truth:  getDefaultLightLaf
# Predicted:
# Ground truth:  findDeclaredAttributeValue
# Predicted:  return
# Ground truth:  getColumnCount
# Predicted:  JBUI.insets(normalInset, normalInset,
# Ground truth:  getTitleInsets
# Predicted:  cancelJob(null);
# Ground truth:  insideReadAction
# Predicted:  this.name;
# Ground truth:  getState
# Predicted:  myPackages
# Ground truth:  getParent
# Predicted:  class loader
# Ground truth:  build
# Predicted:  typeParameter
# Ground truth:  visitClassType
# Predicted:
# Ground truth:  changeAttributesInBatch
# Predicted:  return;
# Ground truth:  addSearchResultsIntoEnd
# Predicted:  myBuildOnMake;
#
# Ground truth:  setBuildOnMake
# Predicted:  file
# Ground truth:  findReferenceAtCaret
# Predicted:  myFontFamily
# Ground truth:  appendStartTags
# Predicted:
# Ground truth:  isFrameworkAvailable
# Predicted:  result;
# Ground truth:  getRoot
# Predicted:  file
# Ground truth:  applyFix
# Predicted:  .
# Ground truth:  hostToInjectedUnescaped
# Predicted:  root.setChecked(false);
# Ground truth:  visit
# Predicted:
# Ground truth:  addImpl
# Predicted:  );handler.getProblemName()handler.getProblemName());
# Ground truth:  visitMethodCallExpression
# Predicted:  TestE<caret>num.ONE, TestE<caret>num.
# Ground truth:  foo
# Predicted:  myDefaultValue;
# Ground truth:  getDefaultValue
# Predicted:
# Ground truth:  assertPair
# Predicted:  setExported(modified.myExported);
#
# Ground truth:  applyChanges
# Predicted:  return
# Ground truth:  getPreviousStatement
# Predicted:  }
# Ground truth:  buildMultiText
# Predicted:  myCurrentScope
# Ground truth:  setCurrentScope
# Predicted:
# Ground truth:  getSignature
# Predicted:   function
# Ground truth:  writeExternal
# Predicted:  myRoot.removeAllChildren();
# Ground truth:  reloadTree
# Predicted:  .
# Ground truth:  run
# Predicted:  return false;
# Ground truth:  startInWriteAction
# Predicted:
# Ground truth:  makeContentReachable
# Predicted:  myHashCodeStepCode;
# Ground truth:  getHashCodeStepCode
# Predicted:  return ID;
# Ground truth:  getId
# Predicted:  if (reference.getQualifier() instanceof PsiMethodReferenceExpression) returnreturn false
# Ground truth:  isAlreadyStaticallyImported
# Predicted:  invertWithinConstraint;
# Ground truth:  isInvertWithinConstraint
# Predicted:  =
# Ground truth:  dontReportRefreshErrors
# Predicted:  childRole.OPERATION_SIGN;
# Ground truth:  getChildRole
# Predicted:  (
# Ground truth:  addSecondCompletionVariants
# Predicted:   function
# Ground truth:  setProperties
# Predicted:  sliceToolwindowSettings.isPreview();
# Ground truth:  isPreview
# Predicted:  b;
# Ground truth:  extracted
# Predicted:  return
# Ground truth:  applyHeavyFilter
# Predicted:  i
# Ground truth:  beforeDocumentChange
# Predicted:  myBaseModel.getDocumentModel();
# Ground truth:  getDocumentModel
# Predicted:  o
# Ground truth:  contains
# Predicted:  e.getPresentation().setEnabledAndVisible(true); e.getPresentation
# Ground truth:  defaultUpdate
# Predicted:
# Ground truth:  tryRegisterSdkDownloadFailureHandler
# Predicted:
# Ground truth:  isEnabledForCaret
# Predicted:  return
# Ground truth:  b
# Predicted:  value;value;default;default;default;
# Ground truth:  scale
# Predicted:  myInvert;
# Ground truth:  isInverted
# Predicted:  value;
# Ground truth:  copyOperation
# Predicted:  =;end);end);end;end;end;
# Ground truth:  getHighlightRange
# Predicted:
# Ground truth:  getSelection
# Predicted:  usageView.waitForUpdateRequestsCompletion();
# Ground truth:  waitForUsages
# Predicted:  myTextLayoutCache.resetToDocumentSize(true);
#
# Ground truth:  reset
# Predicted:  FindModel
# Ground truth:  getFindNextModel
# Predicted:  myChange;
#
# Ground truth:  hashCode
# Predicted:   public
# Ground truth:  getHighlightFile
# Predicted:
# Ground truth:  fileDirty
# Predicted:   def containsValue(value) {
# Ground truth:  contains
# Predicted:  .
# Ground truth:  getId
# Predicted:  caret>
# Ground truth:  getFoo
# Predicted:  current.myPreviousCodeProcessor;
# Ground truth:  setCollectInfo
# Predicted:   def
# Ground truth:  getJigsawOptions
# Predicted:  isCustomScope;
# Ground truth:  isCustomScope
# Predicted:  myColor;
# Ground truth:  getColor
# Predicted:  filter
# Ground truth:  getFilter
# Predicted:
# Ground truth:  updatePreviewVisibility
# Predicted:  myField
# Ground truth:  createDescriptorImpl
# Predicted:
# Ground truth:  reportProblems
# Predicted:
# Ground truth:  select
# Predicted:  f(null);
# Ground truth:  g
# Predicted:   public void rootChanged
# Ground truth:  rootChanged
# Predicted:  .
# Ground truth:  buildTreeModel
# Predicted:  return
# Ground truth:  getModuleScope
# Predicted:  =
# Ground truth:  changedUpdateImpl
# Predicted:  return;
# Ground truth:  applyFix
# Predicted:  .
# Ground truth:  totalRetriedAttempts
# Predicted:  each
# Ground truth:  execute
# Predicted:  serialAnnotationVisitor()
# Ground truth:  buildVisitor
# Predicted:  myRemoteProcessIdleTtlInMs;
# Ground truth:  getRemoteProcessIdleTtlInMs
# Predicted:  event.isEventInsideBalloon(); }
# Ground truth:  canAutohideOn
# Predicted:  model.getRowCount();
# Ground truth:  getModelRowCount
# Predicted:  myDateBefore.setDate(settings.getDateBefore());
#       myDateAfter
# Ground truth:  initValues
# Predicted:  longlonglonglonglonglonglonglonglong
# Ground truth:  getDefiniteRange
# Predicted:
# Ground truth:  loadState
# Predicted:  .
# Ground truth:  isSelected
# Predicted:  printables
# Ground truth:  flushOutputFile
# Predicted:  return false;
# Ground truth:  supportsCustomCreateUI
# Predicted:  myNavigator;
# Ground truth:  getNavigator
# Predicted:  myMainPanel;
# Ground truth:  getComponent
# Predicted:  this.id;
# Ground truth:  getId
# Predicted:   public static
# Ground truth:  getListCellRendererComponent
# Predicted:  mySelectedItem
# Ground truth:  setSelectedItem
# Predicted:
# Ground truth:  deleteChildInternal
# Predicted:  EditorAccessibilityDocument.this;
# Ground truth:  getElement
# Predicted:
# Ground truth:  stopDaemon
# Predicted:  return-1;
# Ground truth:  getNext
# Predicted:  myState.getMagnitude()
# Ground truth:  isPassed
# Predicted:  return;
# Ground truth:  selectionChanged
# Predicted:  myIndent
# Ground truth:  getIndent
# Predicted:   public String
# Ground truth:  serialize
# Predicted:  instance.setProblemBeginOffset(value);
#             instance.setProblemEndOffset(
# Ground truth:  setProblemBeginOffset
# Predicted:
# Ground truth:  createIfInaccessible
# Predicted:   def
# Ground truth:  addContent
# Predicted:   public
# Ground truth:  startDrag
# Predicted:  return;
# Ground truth:  visitInnerClass
# Predicted:
# Ground truth:  createForNonExistingFile
# Predicted:  d;
# Ground truth:  hashCode
# Predicted:   function
# Ground truth:  parseDouble
# Predicted:  module.getIcon());
# Ground truth:  forModule
# Predicted:  orderEntry.name;
# Ground truth:  findLibraryOrderEntry
# Predicted:  changedLines
# Ground truth:  executeWriteAction
# Predicted:  return
# Ground truth:  isStaticsScopeCorrect
# Predicted:  helpFile
# Ground truth:  getMainDocumentation
# Predicted:   def
# Ground truth:  selectWordAtCaret
# Predicted:
# Ground truth:  findAttributeValue
# Predicted:   public String
# Ground truth:  accept
# Predicted:  candidate.getName()
# Ground truth:  isAccepted
# Predicted:  myTableModel.getRowCount();
# Ground truth:  getElementCount
# Predicted:  .
# Ground truth:  getPrevSibling
# Predicted:
# Ground truth:  withRandomAttributeBytes
# Predicted:  )
# Ground truth:  toSearchScope
# Predicted:  myContentEntry.name;
# Ground truth:  init
# Predicted:  var
# Ground truth:  registerEclipseLinkedVarPath
# Predicted:  .
# Ground truth:  isReformatWithContext
# Predicted:  );returnnull;return
# Ground truth:  getLineIndent
# Predicted:  return false;
# Ground truth:  isImplicitRead
# Predicted:   function
# Ground truth:  addCommandListener
# Predicted:  myVisitedColor
# Ground truth:  setVisitedColor
# Predicted:  return;
# Ground truth:  run
# Predicted:  return
# Ground truth:  compare
# Predicted:  type1
# Ground truth:  typesAreEquivalent
# Predicted:   def
# Ground truth:  forRecordedVariableTypes
# Predicted:  list.add();
# Ground truth:  collectTreePaths
# Predicted:
# Ground truth:  createProfilesIniChooserDescriptor
# Predicted:  myPosition.getLine());myPosition.getLine());myPosition.get
# Ground truth:  setMarker
# Predicted:  return false;
# Ground truth:  isSoft
# Predicted:  myHasTrigrams
# Ground truth:  isCovered
# Predicted:  newScheme);
# Ground truth:  exportProjectScheme
# Predicted:  myCompileMessage.hasText()
# Ground truth:  getMessage
# Predicted:  null;
#
# Ground truth:  get
# Predicted:
# Ground truth:  addElementBeforeAnchor
# Predicted:   def
# Ground truth:  zip
# Predicted:  targetClass
# Ground truth:  isValidFor
# Predicted:  component
# Ground truth:  selectAll
# Predicted:  isRetina[1]
# Ground truth:  isRetina
# Predicted:  myBackground
# Ground truth:  processBackground
# Predicted:  myExpectedTypeText
# Ground truth:  findType
# Predicted:  myLookupElements);
# Ground truth:  withPopupAdvertisement
# Predicted:  field
# Ground truth:  buildFix
# Predicted:  return;
# Ground truth:  addFileNamePattern
# Predicted:  myList.getCellBounds(size, size));
# Ground truth:  actionPerformed
# Predicted:  .
# Ground truth:  clear
# Predicted:
# Ground truth:  removeVisibilityIfNeeded
# Predicted:  return LanguageLevel.JDK_21;
# Ground truth:  getLanguageLevel
# Predicted:  .) ;.) ;.) ;.)
# Ground truth:  applyLayoutSettings
# Predicted:  .);
#      return;
#      return;
#
# Ground truth:  applyFix
# Predicted:  () ;
#    () ;
#    ( prevSoftWrap
# Ground truth:  getVisualLineInfo
# Predicted:  it.curChild.name;
# Ground truth:  doPerformChildrenGuidance
# Predicted:  return
# Ground truth:  getChangedScopeAndSeverityEvent
# Predicted:  e.getPresentation().setEnabledAndVisible(true); e.getPresentation
# Ground truth:  update
# Predicted:  labelReachability
# Ground truth:  reportUnreachableSwitchBranches
# Predicted:   public static String
# Ground truth:  main
# Predicted:  size.height = 250;
# Ground truth:  getPreferredSize
# Predicted:  .
# Ground truth:  eventProcessed
# Predicted:   public
# Ground truth:  getProjectRepresentationName
# Predicted:  function
# Ground truth:  createDescriptor
# Predicted:   public static
# Ground truth:  getFastLoadingTimeMillis
# Predicted:
# Ground truth:  fun
# Predicted:
# Ground truth:  setErrorStripeTooltip
# Predicted:
# Ground truth:  hashCode
# Predicted:   def
# Ground truth:  addDependency
# Predicted:  group
# Ground truth:  supportsNamedGroupSyntax
# Predicted:  myCondition;
# Ground truth:  getCondition
# Predicted:  //
# Ground truth:  setMonospacedOnly
# Predicted:  virtualFile.name;
# Ground truth:  processClassPathItems
# Predicted:   def
# Ground truth:  matches
# Predicted:  fileName
# Ground truth:  notTooManyFalsePositivesInIndexLookups
# Predicted:  mySearchCriteriaEdit;
# Ground truth:  getPreferredFocusedComponent
# Predicted:  outermost.getParent();
# Ground truth:  getLoopForLoopCondition
# Predicted:  DEPRECATED_ATTRIBUTES
# Ground truth:  getTextAttributesKey
# Predicted:  virtualFile.getPresentableUrl();
# Ground truth:  getRelativePath
# Predicted:
# Ground truth:  actionPerformed
# Predicted:   public static
# Ground truth:  updateFailedState
# Predicted:  return false;
# Ground truth:  isSingleParameterInfo
# Predicted:  mockInterfaceType
# Ground truth:  createInterfaceType
# Predicted:  endOffsetUpperEstimate
# Ground truth:  getEndOffsetUpperEstimate
# Predicted:  a
# Ground truth:  buildVisitor
# Predicted:  method
# Ground truth:  calculateResult
# Predicted:
# Ground truth:  mouseMoved
# Predicted:  lExpr);
# Ground truth:  visitVariable
# Predicted:  key
# Ground truth:  getShortPath
# Predicted:  return;
# Ground truth:  checkSetterNeeded
# Predicted:   public static
# Ground truth:  createFormBuilder
# Predicted:   public void
# Ground truth:  setExternalSystemIdInInternalStorage
# Predicted:  myThrowable
# Ground truth:  getThrowable
# Predicted:  return
# Ground truth:  addGroupOfTargets
# Predicted:  return;
# Ground truth:  addFileToProcess
# Predicted:  .
# Ground truth:  update
# Predicted:  return false;
# Ground truth:  typeIsConcreteClass
# Predicted:  replaceInline.add(breakStatement); replaceInline.add(breakStatement);
# Ground truth:  moveToBreaks
# Predicted:  myItemPresentation
# Ground truth:  equals
# Predicted:  anchor
# Ground truth:  isHorizontal
# Predicted:
# Ground truth:  addConstantsFromReferencedClassesInSwitch
# Predicted:  return
# Ground truth:  r
# Predicted:
# Ground truth:  actionPerformed
# Predicted:  myColorWidth
# Ground truth:  getColorWidth
# Predicted:  myStarts[index];
# Ground truth:  getLineStart
# Predicted:  library.name = library.name;
# Ground truth:  onLibraryAdded
# Predicted:  myNamemyType.equals(label.myType) &&myVersion.
# Ground truth:  equals
# Predicted:  return false;
# Ground truth:  expressionHasTypeOrSubtype
# Predicted:  myT.name;
# Ground truth:  getMyT
# Predicted:  return;
# Ground truth:  checkAccessStaticMemberViaInstanceReference
# Predicted:  myTree.name;
# Ground truth:  getComponent
# Predicted:   public static String
# Ground truth:  clear
# Predicted:  myEditor.requestUpdate();
# Ground truth:  revalidate
# Predicted:   def
# Ground truth:  setFontSize
# Predicted:  id
# Ground truth:  hashCode
# Predicted:
# Ground truth:  equals
# Predicted:  GROUP
# Ground truth:  getGroup
# Predicted:
# Ground truth:  update
# Predicted:  .
# Ground truth:  run
# Predicted:  castToIncompatibleInterfaceVisitor();
# Ground truth:  buildVisitor
# Predicted:
# Ground truth:  findConversionForVariableReference
# Predicted:  .
# Ground truth:  getInspection
# Predicted:  event
# Ground truth:  fireFileMoved
# Predicted:   public void
# Ground truth:  force
# Predicted:  =
# Ground truth:  compileOnly
# Predicted:  return
# Ground truth:  dispose
# Predicted:  .
# Ground truth:  getClassOfDefaultConstructorFunction
# Predicted:  methodRef = (PsiMethod)methodRef.methodRef.method
# Ground truth:  isResolvedBySecondSearch
# Predicted:  hashCode()
# Ground truth:  hashCode
# Predicted:
# Ground truth:  getPreferredSize
# Predicted:  return
# Ground truth:  hasFailContract
# Predicted:
# Ground truth:  fillUsages
# Predicted:  ..();.() ;
#
# Ground truth:  fixLeftAndBothChangeCase
# Predicted:  .isEmpty()
# Ground truth:  isEmpty
# Predicted:  file
# Ground truth:  actionPerformed
# Predicted:  context.isValid()
# Ground truth:  isAvailable
# Predicted:  myWriteSorted
# Ground truth:  removeConfiguration
# Predicted:  myMap.hashCode();
# Ground truth:  hashCode
# Predicted:   function
# Ground truth:  addCustomSettings
# Predicted:  return;
# Ground truth:  applyFix
# Predicted:  return;
# Ground truth:  showPopup
# Predicted:  left.
# Ground truth:  getCondition
# Predicted:  returnTypeParameter
# Ground truth:  getReturnTypeParameterNotMentionedPreviously
# Predicted:  ApplicationBundle.BUNDLE;
# Ground truth:  getFallbackBundleName
# Predicted:  myRow.name;
# Ground truth:  refreshRow
# Predicted:  PackagingElementWeights.DIRECTORY;
# Ground truth:  getWeight
# Predicted:  return
# Ground truth:  getTagName
# Predicted:  .
# Ground truth:  getSourceScope
# Predicted:
# Ground truth:  newMethod
# Predicted:  return
# Ground truth:  canBeReusedBy
# Predicted:  myTarget.canNavigateToSource(); }
# Ground truth:  canNavigateToSource
# Predicted:  return
# Ground truth:  checkForProblems
# Predicted:  myAnchor;
# Ground truth:  getAnchor
# Predicted:
# Ground truth:  getChosenElement
# Predicted:  object;
# Ground truth:  extractClass
# Predicted:
# Ground truth:  isCancelable
# Predicted:  return;
# Ground truth:  buildVisitor
# Hard score:  0.0014701029072035042
# Soft score:  0.11355751830934176
# Rouge score:  {'rouge1': 0.120547847124721, 'rouge2': 0.046891254463662324, 'rougeL': 0.1189334301092127, 'rougeLsum': 0.11889086305271905}
